# %% [markdown]
# # PyMarek Day 4
#
# Pandas marathon

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
birth_dates = pd.read_csv("http://www.gagolewski.com/resources/data/birth_dates.csv", comment="#")
iris = pd.read_csv("http://www.gagolewski.com/resources/data/iris.csv", comment="#")
tips = pd.read_csv("http://www.gagolewski.com/resources/data/tips.csv", comment="#")
flights = pd.read_csv("http://www.gagolewski.com/resources/data/flights.csv", comment="#")
weather = pd.read_csv("http://www.gagolewski.com/resources/data/nycflights13_weather.csv.gz", comment="#")

# %%
# inheritance

class Dog:
    def __init__(self, name):
        self.name = name
    
    def bark(self):
        print("woof woof hau hau")
    
    def sit(self):
        print("OK.")

# %%
aramis = Dog("Aramis")

# %%
aramis.bark()
# Out:
# woof woof hau hau

# %%
aramis.sit()
# Out:
# OK.

# %%
class Husky(Dog): # each Huskey is a dog, Husky's superclass is Dog
    def __init__(self, name):
        super().__init__(name)
    
    def sit(self): # method overload
        print("No.")
    
    def pull_sleigh(self):
        print('My pleasure')

# %%
mishka = Husky("Mishka")

# %%
mishka.bark()
# Out:
# woof woof hau hau

# %%
mishka.sit()
# Out:
# No.

# %%
# aramis.pull_sleigh()

# %%
mishka.pull_sleigh()
# Out:
# My pleasure

# %%
# In pandas this is also used
tips.groupby('sex')

# %%
tips.groupby('sex').total_bill

# %%
tips.groupby('sex')['total_bill']

# %%
tips.groupby('sex')[['total_bill']]

# %%
tips.groupby('sex').mean()
# Out:
#         total_bill       tip      size
# sex
# Female   18.056897  2.833448  2.459770
# Male     20.744076  3.089618  2.630573

# %%
tips.groupby('sex').total_bill.mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
tips.groupby('sex')[['total_bill']].mean()
# Out:
#         total_bill
# sex
# Female   18.056897
# Male     20.744076

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html

# %%
x = tips.groupby('sex').total_bill
type(x)
# Out:
# pandas.core.groupby.groupby.SeriesGroupBy

# %%
type(x).__bases__
# Out:
# (pandas.core.groupby.groupby.GroupBy,)

# %%
type(tips.groupby('sex')).__bases__[0].__bases__
# Out:
# (pandas.core.groupby.groupby.GroupBy,)

# %%
weather.head()
# Out:
#   origin  year  month  day  hour   temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0  37.04  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1  37.04  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2  37.94  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3  37.94  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4  37.94  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib            time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01 01:00:00
# 1  15.891535     0.0    1013.0   10.0  2013-01-01 02:00:00
# 2  14.567241     0.0    1012.6   10.0  2013-01-01 03:00:00
# 3  15.891535     0.0    1012.7   10.0  2013-01-01 04:00:00
# 4  17.215830     0.0    1012.8   10.0  2013-01-01 05:00:00

# %%
weather.shape
# Out:
# (26130, 15)

# %%
weather.origin.unique()
# Out:
# array(['EWR', 'JFK', 'LGA'], dtype=object)

# %% [markdown]
# With the `weather` data frame from `nycflights13`:
#
#       * Convert temperature to Celsius.
#       * Compute daily mean temperatures for the `JFK` airport.
#       If some hourly temperature measurements is missing,
#       linearly interpolate between the preceding and following non-missing data,
#       e.g., a temperature sequence of `[..., 10, NaN, NaN, 40, ...]`
#       should be transformed to `[..., 10, 20, 30, 40, ...]`.
#       * Present the daily mean temperatures on a plot.
#       The x-axis labels should be human-readable and intuitive.
#       * Choose days with greater mean temperature than in the preceding day.
#       * Find 5 hottest days.

# %%
weather.temp = (weather.temp -32.0) * 5/9
weather.head(2)
# Out:
#   origin  year  month  day  hour  temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0   2.8  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1   2.8  21.92  53.97     230.0    13.80936
#
#    wind_gust  precip  pressure  visib            time_hour
# 0  11.918651     0.0    1013.9   10.0  2013-01-01 01:00:00
# 1  15.891535     0.0    1013.0   10.0  2013-01-01 02:00:00

# %%
# fri

# %%
weather.shape
# Out:
# (26130, 15)

# %%
weather.temp.count()
# Out:
# 26129

# %%
weather.loc[pd.isna(weather.temp),:]
# Out:
#      origin  year  month  day  hour  temp  dewp  humid  wind_dir  wind_speed  \
# 5596    EWR  2013      8   22    13   NaN   NaN    NaN     240.0    12.65858
#
#       wind_gust  precip  pressure  visib            time_hour
# 5596  14.567241    0.03       NaN    4.0  2013-08-22 14:00:00

# %%
weather.iloc[5595:5598,:]
# Out:
#      origin  year  month  day  hour  temp  dewp  humid  wind_dir  wind_speed  \
# 5595    EWR  2013      8   22    12  24.0  71.6  88.59     230.0    11.50780
# 5596    EWR  2013      8   22    13   NaN   NaN    NaN     240.0    12.65858
# 5597    EWR  2013      8   22    14  23.0  71.6  94.10       NaN     3.45234
#
#       wind_gust  precip  pressure  visib            time_hour
# 5595  13.242946    0.00       NaN    9.0  2013-08-22 13:00:00
# 5596  14.567241    0.03       NaN    4.0  2013-08-22 14:00:00
# 5597   3.972884    0.01       NaN    8.0  2013-08-22 15:00:00

# %%
weather.at[5596, 'temp'] = 23.5

# %%
weather.iloc[5595:5598,:]
# Out:
#      origin  year  month  day  hour  temp  dewp  humid  wind_dir  wind_speed  \
# 5595    EWR  2013      8   22    12  24.0  71.6  88.59     230.0    11.50780
# 5596    EWR  2013      8   22    13  23.5   NaN    NaN     240.0    12.65858
# 5597    EWR  2013      8   22    14  23.0  71.6  94.10       NaN     3.45234
#
#       wind_gust  precip  pressure  visib            time_hour
# 5595  13.242946    0.00       NaN    9.0  2013-08-22 13:00:00
# 5596  14.567241    0.03       NaN    4.0  2013-08-22 14:00:00
# 5597   3.972884    0.01       NaN    8.0  2013-08-22 15:00:00

# %%
weather['date'] = [pd.to_datetime(d).date() for d in weather['time_hour']]

# %%
weather['date2'] = pd.to_datetime(weather['time_hour']).dt.date

# %%
weather.head()
# Out:
#   origin  year  month  day  hour  temp   dewp  humid  wind_dir  wind_speed  \
# 0    EWR  2013      1    1     0   2.8  21.92  53.97     230.0    10.35702
# 1    EWR  2013      1    1     1   2.8  21.92  53.97     230.0    13.80936
# 2    EWR  2013      1    1     2   3.3  21.92  52.09     230.0    12.65858
# 3    EWR  2013      1    1     3   3.3  23.00  54.51     230.0    13.80936
# 4    EWR  2013      1    1     4   3.3  24.08  57.04     240.0    14.96014
#
#    wind_gust  precip  pressure  visib            time_hour        date  \
# 0  11.918651     0.0    1013.9   10.0  2013-01-01 01:00:00  2013-01-01
# 1  15.891535     0.0    1013.0   10.0  2013-01-01 02:00:00  2013-01-01
# 2  14.567241     0.0    1012.6   10.0  2013-01-01 03:00:00  2013-01-01
# 3  15.891535     0.0    1012.7   10.0  2013-01-01 04:00:00  2013-01-01
# 4  17.215830     0.0    1012.8   10.0  2013-01-01 05:00:00  2013-01-01
#
#   temp_increase               date2
# 0           NaN 2013-01-01 01:00:00
# 1           NaN 2013-01-01 02:00:00
# 2           NaN 2013-01-01 03:00:00
# 3           NaN 2013-01-01 04:00:00
# 4           NaN 2013-01-01 05:00:00

# %%
jfk = weather.loc[weather.origin == 'JFK',:]

# %%
import matplotlib.pyplot as plt
jfk_mean_temp = jfk.groupby('date').temp.mean()
plt.plot(jfk_mean_temp)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
weather_by_date = weather.groupby('date').mean()
weather_by_date['temp_increase'] = weather_by_date.temp.gt(weather_by_date.temp.shift())
weather_by_date.loc[:,['temp','temp_increase']].head()
# Out:
#                 temp  temp_increase
# date
# 2013-01-01  3.927273          False
# 2013-01-02 -1.762500          False
# 2013-01-03 -1.308333           True
# 2013-01-04  1.144444           True
# 2013-01-05  2.793056           True

# %%
weather_by_date.loc[weather_by_date['temp_increase'],'temp'].head()
# Out:
# date
# 2013-01-03   -1.308333
# 2013-01-04    1.144444
# 2013-01-05    2.793056
# 2013-01-06    3.409722
# 2013-01-07    5.511111
# Name: temp, dtype: float64

# %%
weather_by_date.loc[:,['temp']].sort_values(['temp'], ascending=False).head()
# Out:
#                  temp
# date
# 2013-07-19  32.241667
# 2013-07-18  31.304167
# 2013-07-20  31.050000
# 2013-07-17  30.788889
# 2013-07-16  30.570833

# %%
weather.tempC.interpolate(method='Linear', axis=0, limit_area='inside')

# %% [markdown]
# ## SQL connectivity

# %%
import sqlite3 # zero-conf, lightweight, flat-file DB

# %%
conn = sqlite3.connect('/tmp/nycflight13.sqlite')

# %%
conn

# %%
weather = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_weather.csv.gz",
                          comment="#")
flights = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_flights.csv.gz",
                          comment="#")
airports = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_airports.csv.gz",
                          comment="#")
airlines = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_airlines.csv.gz",
                          comment="#")
planes = pd.read_csv(
    "http://www.gagolewski.com/resources/data/nycflights13_planes.csv.gz",
                          comment="#")

# %%
flights.shape
# Out:
# (336776, 19)

# %%
flights.head(1)
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0  2013      1    1     517.0             515        2.0     830.0
#
#    sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 0             819       11.0      UA    1545  N14228    EWR  IAH     227.0
#
#    distance  hour  minute            time_hour
# 0      1400     5      15  2013-01-01 05:00:00

# %%
airlines.head(1)
# Out:
#   carrier               name
# 0      9E  Endeavor Air Inc.

# %%
airlines.query('carrier == "UA"')
# Out:
#    carrier                   name
# 11      UA  United Air Lines Inc.

# %%
planes.query('tailnum=="N14228"')
# Out:
#     tailnum    year                     type manufacturer    model  engines  \
# 177  N14228  1999.0  Fixed wing multi engine       BOEING  737-824        2
#
#      seats  speed     engine
# 177    149    NaN  Turbo-fan

# %%
airports.query('faa=="EWR"')
# Out:
#      faa                 name      lat        lon  alt  tz dst  \
# 460  EWR  Newark Liberty Intl  40.6925 -74.168667   18  -5   A
#
#                 tzone
# 460  America/New_York

# %%
# let's use a low-level Python interface to export airlines to SQL db
airlines.head()
# Out:
#   carrier                    name
# 0      9E       Endeavor Air Inc.
# 1      AA  American Airlines Inc.
# 2      AS    Alaska Airlines Inc.
# 3      B6         JetBlue Airways
# 4      DL    Delta Air Lines Inc.

# %%
conn.execute('''
CREATE TABLE airlines_temp (
    carrier CHAR(2) PRIMARY KEY,
    name VARCHAR(64)
)
''')

conn.commit()

# %%
list(airlines.to_records(index=False))[:3]
# Out:
# [('9E', 'Endeavor Air Inc.'),
#  ('AA', 'American Airlines Inc.'),
#  ('AS', 'Alaska Airlines Inc.')]

# %%
conn.executemany('''
INSERT INTO airlines_temp (carrier, name) VALUES (?,?)
''', airlines.to_records(index=False))

conn.commit()

# %%
cur = conn.execute("SELECT * FROM airlines_temp WHERE name LIKE '%america%'")
res = cur.fetchall()

# %%
res
# Out:
# [('AA', 'American Airlines Inc.'), ('VX', 'Virgin America')]

# %%
pd.DataFrame.from_records(res)
# Out:
#     0                       1
# 0  AA  American Airlines Inc.
# 1  VX          Virgin America

# %% [markdown]
# ## Pandas interface to SQL

# %%
# import sqlite3
# conn = sqlite3.connect("/temp/nycflight13.sqLite")

weather.to_sql("weather", conn)
flights.to_sql("flights", conn)
airports.to_sql("airports", conn)
airlines.to_sql("airlines", conn)
planes.to_sql("planes", conn)
# CREATE TABLE, INSERT INTO

# %%
pd.read_sql_query('''
SELECT * FROM airlines WHERE name LIKE "%america%"
''', conn)
# Out:
#    index carrier                    name
# 0      1      AA  American Airlines Inc.
# 1     13      VX          Virgin America

# %% [markdown]
# Marek Gagolewski:
#    1. `SELECT DISTINCT engine FROM planes`
#    2. `SELECT DISTINCT type, engine FROM planes`
#    3. `SELECT COUNT(*), engine FROM planes GROUP BY engine`
#    4. `SELECT COUNT(*), engine, type FROM planes GROUP BY engine, type`
#    5. `SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer FROM planes GROUP BY engine, manufacturer`

# %%
pd.read_sql_query('''
SELECT DISTINCT engine FROM planes
''', conn)
# Out:
#           engine
# 0      Turbo-fan
# 1      Turbo-jet
# 2  Reciprocating
# 3        4 Cycle
# 4    Turbo-shaft
# 5     Turbo-prop

# %%
planes.head(1)
# Out:
#   tailnum    year                     type manufacturer      model  engines  \
# 0  N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#    seats  speed     engine
# 0     55    NaN  Turbo-fan

# %%
pd.DataFrame(planes.engine.unique(), columns=['engine'])
# Out:
#           engine
# 0      Turbo-fan
# 1      Turbo-jet
# 2  Reciprocating
# 3        4 Cycle
# 4    Turbo-shaft
# 5     Turbo-prop

# %%
pd.read_sql_query('''
SELECT DISTINCT type, engine FROM planes
''', conn)
# Out:
#                        type         engine
# 0   Fixed wing multi engine      Turbo-fan
# 1   Fixed wing multi engine      Turbo-jet
# 2  Fixed wing single engine  Reciprocating
# 3   Fixed wing multi engine  Reciprocating
# 4  Fixed wing single engine        4 Cycle
# 5                Rotorcraft    Turbo-shaft
# 6   Fixed wing multi engine     Turbo-prop

# %%
planes.groupby(['type', 'engine']).count().reset_index().loc[:,['type', 'engine']]
# Out:
#                        type         engine
# 0   Fixed wing multi engine  Reciprocating
# 1   Fixed wing multi engine      Turbo-fan
# 2   Fixed wing multi engine      Turbo-jet
# 3   Fixed wing multi engine     Turbo-prop
# 4  Fixed wing single engine        4 Cycle
# 5  Fixed wing single engine  Reciprocating
# 6                Rotorcraft    Turbo-shaft

# %%
pd.read_sql_query('''
SELECT COUNT(*), engine FROM planes GROUP BY engine
''', conn)
# Out:
#    COUNT(*)         engine
# 0         2        4 Cycle
# 1        28  Reciprocating
# 2      2750      Turbo-fan
# 3       535      Turbo-jet
# 4         2     Turbo-prop
# 5         5    Turbo-shaft

# %%
planes.groupby('engine').size().rename('count').reset_index()
# Out:
#           engine  count
# 0        4 Cycle      2
# 1  Reciprocating     28
# 2      Turbo-fan   2750
# 3      Turbo-jet    535
# 4     Turbo-prop      2
# 5    Turbo-shaft      5

# %%
planes.reset_index().loc[:,['index','engine']].groupby('engine').count().reset_index()
# Out:
#           engine  index
# 0        4 Cycle      2
# 1  Reciprocating     28
# 2      Turbo-fan   2750
# 3      Turbo-jet    535
# 4     Turbo-prop      2
# 5    Turbo-shaft      5

# %%
pd.read_sql_query('''
SELECT COUNT(*), engine, type FROM planes GROUP BY engine, type
''', conn)
# Out:
#    COUNT(*)         engine                      type
# 0         2        4 Cycle  Fixed wing single engine
# 1         5  Reciprocating   Fixed wing multi engine
# 2        23  Reciprocating  Fixed wing single engine
# 3      2750      Turbo-fan   Fixed wing multi engine
# 4       535      Turbo-jet   Fixed wing multi engine
# 5         2     Turbo-prop   Fixed wing multi engine
# 6         5    Turbo-shaft                Rotorcraft

# %%
planes.groupby(['engine', 'type']).size().rename('count').reset_index()
# Out:
#           engine                      type  count
# 0        4 Cycle  Fixed wing single engine      2
# 1  Reciprocating   Fixed wing multi engine      5
# 2  Reciprocating  Fixed wing single engine     23
# 3      Turbo-fan   Fixed wing multi engine   2750
# 4      Turbo-jet   Fixed wing multi engine    535
# 5     Turbo-prop   Fixed wing multi engine      2
# 6    Turbo-shaft                Rotorcraft      5

# %%
planes.reset_index().loc[:,['index','engine','type']].groupby(['engine', 'type']).count().reset_index()
# Out:
#           engine                      type  index
# 0        4 Cycle  Fixed wing single engine      2
# 1  Reciprocating   Fixed wing multi engine      5
# 2  Reciprocating  Fixed wing single engine     23
# 3      Turbo-fan   Fixed wing multi engine   2750
# 4      Turbo-jet   Fixed wing multi engine    535
# 5     Turbo-prop   Fixed wing multi engine      2
# 6    Turbo-shaft                Rotorcraft      5

# %%
pd.read_sql_query('''
SELECT MIN(year), AVG(year), MAX(year), engine, manufacturer FROM planes GROUP BY engine, manufacturer
''', conn)
# Out:
#     MIN(year)    AVG(year)  MAX(year)         engine  \
# 0      1975.0  1975.000000     1975.0        4 Cycle
# 1         NaN          NaN        NaN        4 Cycle
# 2         NaN          NaN        NaN  Reciprocating
# 3      2007.0  2007.000000     2007.0  Reciprocating
# 4         NaN          NaN        NaN  Reciprocating
# 5      1959.0  1971.142857     1983.0  Reciprocating
# 6      2007.0  2007.000000     2007.0  Reciprocating
# 7      1959.0  1959.000000     1959.0  Reciprocating
# 8      1956.0  1956.000000     1956.0  Reciprocating
# 9      2007.0  2007.000000     2007.0  Reciprocating
# 10        NaN          NaN        NaN  Reciprocating
# 11     1985.0  1985.000000     1985.0  Reciprocating
# 12        NaN          NaN        NaN  Reciprocating
# 13     1985.0  1985.000000     1985.0  Reciprocating
# 14     1993.0  1993.000000     1993.0  Reciprocating
# 15        NaN          NaN        NaN  Reciprocating
# 16     1968.0  1976.400000     1980.0  Reciprocating
# 17     1985.0  1985.000000     1985.0  Reciprocating
# 18     2002.0  2007.281734     2013.0      Turbo-fan
# 19     1992.0  1998.599251     2013.0      Turbo-fan
# 20     1986.0  1986.000000     1986.0      Turbo-fan
# 21     1965.0  2001.210400     2013.0      Turbo-fan
# 22     1998.0  2004.486188     2013.0      Turbo-fan
# 23     1997.0  1997.333333     1998.0      Turbo-fan
# 24     1979.0  1979.000000     1979.0      Turbo-fan
# 25     1998.0  2003.613014     2013.0      Turbo-fan
# 26     1992.0  1992.000000     1992.0      Turbo-fan
# 27        NaN          NaN        NaN      Turbo-fan
# 28     1986.0  1989.704545     1997.0      Turbo-fan
# 29     1987.0  1989.737864     1993.0      Turbo-fan
# 30     2002.0  2002.000000     2002.0      Turbo-jet
# 31     1989.0  1997.439024     2004.0      Turbo-jet
# 32     1984.0  1996.368272     2005.0      Turbo-jet
# 33     1974.0  1974.000000     1974.0      Turbo-jet
# 34     1999.0  1999.000000     1999.0      Turbo-jet
# 35     1976.0  1976.000000     1976.0      Turbo-jet
# 36     1975.0  1990.714286     1998.0      Turbo-jet
# 37     1991.0  1991.928571     1992.0      Turbo-jet
# 38     1967.0  1969.500000     1972.0     Turbo-prop
# 39     2001.0  2001.000000     2001.0    Turbo-shaft
# 40     1975.0  1984.500000     1994.0    Turbo-shaft
# 41     2012.0  2012.000000     2012.0    Turbo-shaft
# 42     1985.0  1985.000000     1985.0    Turbo-shaft
#
#                      manufacturer
# 0                          CESSNA
# 1                     JOHN G HESS
# 2           AMERICAN AIRCRAFT INC
# 3              AVIAT AIRCRAFT INC
# 4                   BARKER JACK L
# 5                          CESSNA
# 6              CIRRUS DESIGN CORP
# 7                     DEHAVILLAND
# 8                         DOUGLAS
# 9                  FRIEDEMANN JON
# 10             HURLEY JAMES LARRY
# 11                   KILDALL GARY
# 12                LAMBERT RICHARD
# 13                LEBLANC GLENN T
# 14                     MARZ BARRY
# 15                    PAIR MIKE E
# 16                          PIPER
# 17                   STEWART MACO
# 18                         AIRBUS
# 19               AIRBUS INDUSTRIE
# 20         AVIONS MARCEL DASSAULT
# 21                         BOEING
# 22                 BOMBARDIER INC
# 23                       CANADAIR
# 24                         CESSNA
# 25                        EMBRAER
# 26           GULFSTREAM AEROSPACE
# 27                    LEARJET INC
# 28              MCDONNELL DOUGLAS
# 29  MCDONNELL DOUGLAS AIRCRAFT CO
# 30                         AIRBUS
# 31               AIRBUS INDUSTRIE
# 32                         BOEING
# 33                   CANADAIR LTD
# 34                        EMBRAER
# 35           GULFSTREAM AEROSPACE
# 36              MCDONNELL DOUGLAS
# 37  MCDONNELL DOUGLAS CORPORATION
# 38                          BEECH
# 39                     AGUSTA SPA
# 40                           BELL
# 41         ROBINSON HELICOPTER CO
# 42                       SIKORSKY

# %%
planes.loc[:,['year','engine','manufacturer']].groupby(['engine', 'manufacturer']).agg({
                         'year':['min', 'max', 'mean']})['year']
# Out:
#                                                 min     max         mean
# engine        manufacturer
# 4 Cycle       CESSNA                         1975.0  1975.0  1975.000000
#               JOHN G HESS                       NaN     NaN          NaN
# Reciprocating AMERICAN AIRCRAFT INC             NaN     NaN          NaN
#               AVIAT AIRCRAFT INC             2007.0  2007.0  2007.000000
#               BARKER JACK L                     NaN     NaN          NaN
#               CESSNA                         1959.0  1983.0  1971.142857
#               CIRRUS DESIGN CORP             2007.0  2007.0  2007.000000
#               DEHAVILLAND                    1959.0  1959.0  1959.000000
#               DOUGLAS                        1956.0  1956.0  1956.000000
#               FRIEDEMANN JON                 2007.0  2007.0  2007.000000
#               HURLEY JAMES LARRY                NaN     NaN          NaN
#               KILDALL GARY                   1985.0  1985.0  1985.000000
#               LAMBERT RICHARD                   NaN     NaN          NaN
#               LEBLANC GLENN T                1985.0  1985.0  1985.000000
#               MARZ BARRY                     1993.0  1993.0  1993.000000
#               PAIR MIKE E                       NaN     NaN          NaN
#               PIPER                          1968.0  1980.0  1976.400000
#               STEWART MACO                   1985.0  1985.0  1985.000000
# Turbo-fan     AIRBUS                         2002.0  2013.0  2007.281734
#               AIRBUS INDUSTRIE               1992.0  2013.0  1998.599251
#               AVIONS MARCEL DASSAULT         1986.0  1986.0  1986.000000
#               BOEING                         1965.0  2013.0  2001.210400
#               BOMBARDIER INC                 1998.0  2013.0  2004.486188
#               CANADAIR                       1997.0  1998.0  1997.333333
#               CESSNA                         1979.0  1979.0  1979.000000
#               EMBRAER                        1998.0  2013.0  2003.613014
#               GULFSTREAM AEROSPACE           1992.0  1992.0  1992.000000
#               LEARJET INC                       NaN     NaN          NaN
#               MCDONNELL DOUGLAS              1986.0  1997.0  1989.704545
#               MCDONNELL DOUGLAS AIRCRAFT CO  1987.0  1993.0  1989.737864
# Turbo-jet     AIRBUS                         2002.0  2002.0  2002.000000
#               AIRBUS INDUSTRIE               1989.0  2004.0  1997.439024
#               BOEING                         1984.0  2005.0  1996.368272
#               CANADAIR LTD                   1974.0  1974.0  1974.000000
#               EMBRAER                        1999.0  1999.0  1999.000000
#               GULFSTREAM AEROSPACE           1976.0  1976.0  1976.000000
#               MCDONNELL DOUGLAS              1975.0  1998.0  1990.714286
#               MCDONNELL DOUGLAS CORPORATION  1991.0  1992.0  1991.928571
# Turbo-prop    BEECH                          1967.0  1972.0  1969.500000
# Turbo-shaft   AGUSTA SPA                     2001.0  2001.0  2001.000000
#               BELL                           1975.0  1994.0  1984.500000
#               ROBINSON HELICOPTER CO         2012.0  2012.0  2012.000000
#               SIKORSKY                       1985.0  1985.0  1985.000000

# %% [markdown]
# Marek Gagolewski: Consider the birth_dates data set. Write a function that
# returns the names of people which -- at a given date -- have already been born
# but are less than 16 years of age.
#
# Marek Gagolewski: birth_dates = pd.read_csv("http://www.gagolewski.com/resources/data/birth_dates.csv", comment="#")

# %%
birth_dates = pd.read_csv("http://www.gagolewski.com/resources/data/birth_dates.csv", comment="#")

# %%
import datetime

# %%
birth_dates.head()
# Out:
#                Name   BirthDate
# 0    Hung Hyun-Seok  12.06.2000
# 1  Benno Blumenthal  31.12.1918
# 2  Paitoon Ornwimol  26.06.1958
# 3    P'yon Yong-Sun  10.07.1947
# 4    Étienne Chaney  04.09.1983

# %% [markdown]
# 6. `SELECT * FROM planes WHERE speed IS NOT NULL`
#    7. `SELECT tailnum FROM planes WHERE seats BETWEEN 150 AND 190 AND year >= 2012`
#    8. `SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats>390`
#    9. `SELECT DISTINCT year, seats  FROM planes WHERE year >= 2012 ORDER BY year ASC, seats DESC`
#    10. `SELECT DISTINCT year, seats  FROM planes WHERE year >= 2012 ORDER BY seats DESC, year ASC`

# %%
pd.read_sql_query('''
SELECT * FROM planes WHERE speed IS NOT NULL
''', conn).head()
# Out:
#    index tailnum    year                      type manufacturer      model  \
# 0    424  N201AA  1959.0  Fixed wing single engine       CESSNA        150
# 1    427  N202AA  1980.0   Fixed wing multi engine       CESSNA       421C
# 2    821  N350AA  1980.0   Fixed wing multi engine        PIPER  PA-31-350
# 3    893  N364AA  1973.0   Fixed wing multi engine       CESSNA       310Q
# 4   1027  N378AA  1963.0  Fixed wing single engine       CESSNA       172E
#
#    engines  seats  speed         engine
# 0        1      2   90.0  Reciprocating
# 1        2      8   90.0  Reciprocating
# 2        2      8  162.0  Reciprocating
# 3        2      6  167.0  Reciprocating
# 4        1      4  105.0  Reciprocating

# %%
planes.loc[~planes.speed.isna(),:]

# %%
planes.query('speed != "Nan"').head(2).reset_index()
# Out:
#    index tailnum    year                      type manufacturer model  \
# 0    424  N201AA  1959.0  Fixed wing single engine       CESSNA   150
# 1    427  N202AA  1980.0   Fixed wing multi engine       CESSNA  421C
#
#    engines  seats  speed         engine
# 0        1      2   90.0  Reciprocating
# 1        2      8   90.0  Reciprocating

# %%
pd.read_sql_query('''
SELECT tailnum FROM planes WHERE seats BETWEEN 150 AND 190 AND year >= 2012
''', conn).head(2)
# Out:
#   tailnum
# 0  N361VA
# 1  N849VA

# %%
planes.query('150 <= seats <= 190 and year >=2012').reset_index().loc[:,['tailnum']].head(2)
# Out:
#   tailnum
# 0  N361VA
# 1  N849VA

# %%
pd.read_sql_query('''
SELECT * FROM planes WHERE manufacturer IN ("BOEING", "AIRBUS", "EMBRAER") AND seats>390
''', conn).head(2)
# Out:
#    index tailnum    year                     type manufacturer    model  \
# 0    439  N206UA  1999.0  Fixed wing multi engine       BOEING  777-222
# 1    484  N228UA  2002.0  Fixed wing multi engine       BOEING  777-222
#
#    engines  seats speed     engine
# 0        2    400  None  Turbo-fan
# 1        2    400  None  Turbo-fan

# %%
planes.query('manufacturer in ["BOEING", "AIRBUS", "EMBRAER"] and seats > 390').reset_index().head(2)
# Out:
#    index tailnum    year                     type manufacturer    model  \
# 0    439  N206UA  1999.0  Fixed wing multi engine       BOEING  777-222
# 1    484  N228UA  2002.0  Fixed wing multi engine       BOEING  777-222
#
#    engines  seats  speed     engine
# 0        2    400    NaN  Turbo-fan
# 1        2    400    NaN  Turbo-fan

# %%
pd.read_sql_query('''
SELECT DISTINCT year, seats  FROM planes WHERE year >= 2012 ORDER BY year ASC, seats DESC
''', conn).head(2)
# Out:
#      year  seats
# 0  2012.0    379
# 1  2012.0    377

# %%
(
    planes.query('year >= 2012').groupby(['year', 'seats']).mean().reset_index().loc[:,['year', 'seats']]
    .sort_values(['year','seats'], ascending=[True,False]).reset_index(drop=True).head(5)
)
# Out:
#      year  seats
# 0  2012.0    379
# 1  2012.0    377
# 2  2012.0    260
# 3  2012.0    222
# 4  2012.0    200

# %%
(
    planes.query('year >= 2012').loc[:,['year', 'seats']].drop_duplicates()
    .sort_values(['year','seats'], ascending=[True,False]).reset_index(drop=True).head(5)
)
# Out:
#      year  seats
# 0  2012.0    379
# 1  2012.0    377
# 2  2012.0    260
# 3  2012.0    222
# 4  2012.0    200

# %%
pd.read_sql_query('''
SELECT DISTINCT year, seats  FROM planes WHERE year >= 2012 ORDER BY seats DESC, year ASC
''', conn).head(2)
# Out:
#      year  seats
# 0  2012.0    379
# 1  2013.0    379

# %%
(
    planes.query('year >= 2012').groupby(['year', 'seats']).mean().reset_index().loc[:,['year', 'seats']]
    .sort_values(['seats','year'], ascending=[False,True]).reset_index(drop=True).head(5)
)
# Out:
#      year  seats
# 0  2012.0    379
# 1  2013.0    379
# 2  2012.0    377
# 3  2013.0    377
# 4  2012.0    260

# %% [markdown]
# 11. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer
# 12. SELECT manufacturer, COUNT(*) FROM planes GROUP BY manufacturer HAVING COUNT(*) > 10
# 13. SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer HAVING COUNT(*) > 10
# 14. SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany DESC LIMIT 5

# %%
pd.read_sql_query('''
SELECT manufacturer, COUNT(*) FROM planes WHERE seats > 200 GROUP BY manufacturer
''', conn)
# Out:
#        manufacturer  COUNT(*)
# 0            AIRBUS        66
# 1  AIRBUS INDUSTRIE         4
# 2            BOEING       225

# %%
planes.query('seats > 200').groupby('manufacturer').size().reset_index()
# Out:
#        manufacturer    0
# 0            AIRBUS   66
# 1  AIRBUS INDUSTRIE    4
# 2            BOEING  225

# %%
pd.read_sql_query('''
SELECT manufacturer, COUNT() FROM planes GROUP BY manufacturer HAVING COUNT() > 10
''', conn)
# Out:
#                     manufacturer  COUNT()
# 0                         AIRBUS      336
# 1               AIRBUS INDUSTRIE      400
# 2                         BOEING     1630
# 3                 BOMBARDIER INC      368
# 4                        EMBRAER      299
# 5              MCDONNELL DOUGLAS      120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO      103
# 7  MCDONNELL DOUGLAS CORPORATION       14

# %%
planes.groupby('manufacturer').size().rename('count').reset_index().query('count > 10').reset_index(drop=True)
# Out:
#                     manufacturer  count
# 0                         AIRBUS    336
# 1               AIRBUS INDUSTRIE    400
# 2                         BOEING   1630
# 3                 BOMBARDIER INC    368
# 4                        EMBRAER    299
# 5              MCDONNELL DOUGLAS    120
# 6  MCDONNELL DOUGLAS AIRCRAFT CO    103
# 7  MCDONNELL DOUGLAS CORPORATION     14

# %%
pd.read_sql_query('''
SELECT manufacturer, COUNT() FROM planes WHERE seats > 200 GROUP BY manufacturer HAVING COUNT() > 10
''', conn)
# Out:
#   manufacturer  COUNT()
# 0       AIRBUS       66
# 1       BOEING      225

# %%
(
    planes.query('seats > 200').groupby('manufacturer').size().rename('count').reset_index().
    query('count > 10').reset_index(drop=True)
)
# Out:
#   manufacturer  count
# 0       AIRBUS     66
# 1       BOEING    225

# %%
pd.read_sql_query('''
SELECT manufacturer, COUNT(*) AS howmany FROM planes GROUP BY manufacturer ORDER BY howmany DESC LIMIT 5
''', conn).head(5)
# Out:
#        manufacturer  howmany
# 0            BOEING     1630
# 1  AIRBUS INDUSTRIE      400
# 2    BOMBARDIER INC      368
# 3            AIRBUS      336
# 4           EMBRAER      299

# %%
planes.groupby('manufacturer').size().rename('howmany').sort_values(ascending=False).reset_index().head(5)
# Out:
#        manufacturer  howmany
# 0            BOEING     1630
# 1  AIRBUS INDUSTRIE      400
# 2    BOMBARDIER INC      368
# 3            AIRBUS      336
# 4           EMBRAER      299

# %%
planes.groupby('manufacturer').size().rename('howmany').nlargest(5).reset_index()
# Out:
#        manufacturer  howmany
# 0            BOEING     1630
# 1  AIRBUS INDUSTRIE      400
# 2    BOMBARDIER INC      368
# 3            AIRBUS      336
# 4           EMBRAER      299

# %% [markdown]
# 15. `SELECT * FROM flights LEFT JOIN planes ON flights.tailnum=planes.tailnum`
# 16. ```
#       SELECT planes.*, airlines.* FROM
#        (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
#       INNER JOIN planes ON cartail.tailnum=planes.tailnum
#       INNER JOIN airlines ON cartail.carrier=airlines.carrier
#       ```
#    17.
#
#       ```
#       SELECT flights2.*, weather2.atemp, weather2.ahumid, weather2.apressure FROM
#          (SELECT * FROM flights WHERE origin='EWR') AS flights2
#       LEFT JOIN
#          (SELECT year, month, day, AVG(temp) AS atemp,
#            AVG(humid) AS ahumid, AVG(pressure) AS apressure
#           FROM weather WHERE origin='EWR' GROUP BY year, month, day) AS weather2
#       ON flights2.year=weather2.year
#         AND flights2.month=weather2.month
#         AND flights2.day=weather2.day
#       ```

# %%
pd.read_sql_query('''
SELECT * FROM flights LEFT JOIN planes ON flights.tailnum=planes.tailnum
''', conn).head(5)
# Out:
#   index  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0     0  2013      1    1     517.0             515        2.0     830.0
# 1     1  2013      1    1     533.0             529        4.0     850.0
# 2     2  2013      1    1     542.0             540        2.0     923.0
# 3     3  2013      1    1     544.0             545       -1.0    1004.0
# 4     4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay    ...       index  tailnum    year  \
# 0             819       11.0    ...       177.0   N14228  1999.0
# 1             830       20.0    ...       515.0   N24211  1998.0
# 2             850       33.0    ...      1880.0   N619AA  1990.0
# 3            1022      -18.0    ...      2554.0   N804JB  2012.0
# 4             837      -25.0    ...      2088.0   N668DN  1991.0
#
#                       type manufacturer     model  engines  seats  speed  \
# 0  Fixed wing multi engine       BOEING   737-824      2.0  149.0    NaN
# 1  Fixed wing multi engine       BOEING   737-824      2.0  149.0    NaN
# 2  Fixed wing multi engine       BOEING   757-223      2.0  178.0    NaN
# 3  Fixed wing multi engine       AIRBUS  A320-232      2.0  200.0    NaN
# 4  Fixed wing multi engine       BOEING   757-232      2.0  178.0    NaN
#
#       engine
# 0  Turbo-fan
# 1  Turbo-fan
# 2  Turbo-fan
# 3  Turbo-fan
# 4  Turbo-fan
#
# [5 rows x 30 columns]

# %%
flights.join(planes.set_index('tailnum'), on='tailnum', lsuffix='_left', rsuffix='_right')
#flights.set_index('tailnum').join(planes.set_index('tailnum'))
# Out:
#         year_left  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0            2013      1    1     517.0             515        2.0     830.0
# 1            2013      1    1     533.0             529        4.0     850.0
# 2            2013      1    1     542.0             540        2.0     923.0
# 3            2013      1    1     544.0             545       -1.0    1004.0
# 4            2013      1    1     554.0             600       -6.0     812.0
# 5            2013      1    1     554.0             558       -4.0     740.0
# 6            2013      1    1     555.0             600       -5.0     913.0
# 7            2013      1    1     557.0             600       -3.0     709.0
# 8            2013      1    1     557.0             600       -3.0     838.0
# 9            2013      1    1     558.0             600       -2.0     753.0
# 10           2013      1    1     558.0             600       -2.0     849.0
# 11           2013      1    1     558.0             600       -2.0     853.0
# 12           2013      1    1     558.0             600       -2.0     924.0
# 13           2013      1    1     558.0             600       -2.0     923.0
# 14           2013      1    1     559.0             600       -1.0     941.0
# 15           2013      1    1     559.0             559        0.0     702.0
# 16           2013      1    1     559.0             600       -1.0     854.0
# 17           2013      1    1     600.0             600        0.0     851.0
# 18           2013      1    1     600.0             600        0.0     837.0
# 19           2013      1    1     601.0             600        1.0     844.0
# 20           2013      1    1     602.0             610       -8.0     812.0
# 21           2013      1    1     602.0             605       -3.0     821.0
# 22           2013      1    1     606.0             610       -4.0     858.0
# 23           2013      1    1     606.0             610       -4.0     837.0
# 24           2013      1    1     607.0             607        0.0     858.0
# 25           2013      1    1     608.0             600        8.0     807.0
# 26           2013      1    1     611.0             600       11.0     945.0
# 27           2013      1    1     613.0             610        3.0     925.0
# 28           2013      1    1     615.0             615        0.0    1039.0
# 29           2013      1    1     615.0             615        0.0     833.0
# ...           ...    ...  ...       ...             ...        ...       ...
# 336746       2013      9   30    2123.0            2125       -2.0    2223.0
# 336747       2013      9   30    2127.0            2129       -2.0    2314.0
# 336748       2013      9   30    2128.0            2130       -2.0    2328.0
# 336749       2013      9   30    2129.0            2059       30.0    2230.0
# 336750       2013      9   30    2131.0            2140       -9.0    2225.0
# 336751       2013      9   30    2140.0            2140        0.0      10.0
# 336752       2013      9   30    2142.0            2129       13.0    2250.0
# 336753       2013      9   30    2145.0            2145        0.0     115.0
# 336754       2013      9   30    2147.0            2137       10.0      30.0
# 336755       2013      9   30    2149.0            2156       -7.0    2245.0
# 336756       2013      9   30    2150.0            2159       -9.0    2250.0
# 336757       2013      9   30    2159.0            1845      194.0    2344.0
# 336758       2013      9   30    2203.0            2205       -2.0    2339.0
# 336759       2013      9   30    2207.0            2140       27.0    2257.0
# 336760       2013      9   30    2211.0            2059       72.0    2339.0
# 336761       2013      9   30    2231.0            2245      -14.0    2335.0
# 336762       2013      9   30    2233.0            2113       80.0     112.0
# 336763       2013      9   30    2235.0            2001      154.0      59.0
# 336764       2013      9   30    2237.0            2245       -8.0    2345.0
# 336765       2013      9   30    2240.0            2245       -5.0    2334.0
# 336766       2013      9   30    2240.0            2250      -10.0    2347.0
# 336767       2013      9   30    2241.0            2246       -5.0    2345.0
# 336768       2013      9   30    2307.0            2255       12.0    2359.0
# 336769       2013      9   30    2349.0            2359      -10.0     325.0
# 336770       2013      9   30       NaN            1842        NaN       NaN
# 336771       2013      9   30       NaN            1455        NaN       NaN
# 336772       2013      9   30       NaN            2200        NaN       NaN
# 336773       2013      9   30       NaN            1210        NaN       NaN
# 336774       2013      9   30       NaN            1159        NaN       NaN
# 336775       2013      9   30       NaN             840        NaN       NaN
#
#         sched_arr_time  arr_delay carrier    ...      minute  \
# 0                  819       11.0      UA    ...          15
# 1                  830       20.0      UA    ...          29
# 2                  850       33.0      AA    ...          40
# 3                 1022      -18.0      B6    ...          45
# 4                  837      -25.0      DL    ...           0
# 5                  728       12.0      UA    ...          58
# 6                  854       19.0      B6    ...           0
# 7                  723      -14.0      EV    ...           0
# 8                  846       -8.0      B6    ...           0
# 9                  745        8.0      AA    ...           0
# 10                 851       -2.0      B6    ...           0
# 11                 856       -3.0      B6    ...           0
# 12                 917        7.0      UA    ...           0
# 13                 937      -14.0      UA    ...           0
# 14                 910       31.0      AA    ...           0
# 15                 706       -4.0      B6    ...          59
# 16                 902       -8.0      UA    ...           0
# 17                 858       -7.0      B6    ...           0
# 18                 825       12.0      MQ    ...           0
# 19                 850       -6.0      B6    ...           0
# 20                 820       -8.0      DL    ...          10
# 21                 805       16.0      MQ    ...           5
# 22                 910      -12.0      AA    ...          10
# 23                 845       -8.0      DL    ...          10
# 24                 915      -17.0      UA    ...           7
# 25                 735       32.0      MQ    ...           0
# 26                 931       14.0      UA    ...           0
# 27                 921        4.0      B6    ...          10
# 28                1100      -21.0      B6    ...          15
# 29                 842       -9.0      DL    ...          15
# ...                ...        ...     ...    ...         ...
# 336746            2247      -24.0      EV    ...          25
# 336747            2323       -9.0      EV    ...          29
# 336748            2359      -31.0      B6    ...          30
# 336749            2232       -2.0      EV    ...          59
# 336750            2255      -30.0      MQ    ...          40
# 336751              40      -30.0      AA    ...          40
# 336752            2239       11.0      EV    ...          29
# 336753             140      -25.0      B6    ...          45
# 336754              27        3.0      B6    ...          37
# 336755            2308      -23.0      UA    ...          56
# 336756            2306      -16.0      EV    ...          59
# 336757            2030      194.0      9E    ...          45
# 336758            2331        8.0      EV    ...           5
# 336759            2250        7.0      MQ    ...          40
# 336760            2242       57.0      EV    ...          59
# 336761            2356      -21.0      B6    ...          45
# 336762              30       42.0      UA    ...          13
# 336763            2249      130.0      B6    ...           1
# 336764            2353       -8.0      B6    ...          45
# 336765            2351      -17.0      B6    ...          45
# 336766               7      -20.0      B6    ...          50
# 336767               1      -16.0      B6    ...          46
# 336768            2358        1.0      B6    ...          55
# 336769             350      -25.0      B6    ...          59
# 336770            2019        NaN      EV    ...          42
# 336771            1634        NaN      9E    ...          55
# 336772            2312        NaN      9E    ...           0
# 336773            1330        NaN      MQ    ...          10
# 336774            1344        NaN      MQ    ...          59
# 336775            1020        NaN      MQ    ...          40
#
#                   time_hour year_right                     type  \
# 0       2013-01-01 05:00:00     1999.0  Fixed wing multi engine
# 1       2013-01-01 05:00:00     1998.0  Fixed wing multi engine
# 2       2013-01-01 05:00:00     1990.0  Fixed wing multi engine
# 3       2013-01-01 05:00:00     2012.0  Fixed wing multi engine
# 4       2013-01-01 06:00:00     1991.0  Fixed wing multi engine
# 5       2013-01-01 05:00:00     2012.0  Fixed wing multi engine
# 6       2013-01-01 06:00:00     2000.0  Fixed wing multi engine
# 7       2013-01-01 06:00:00     1998.0  Fixed wing multi engine
# 8       2013-01-01 06:00:00     2004.0  Fixed wing multi engine
# 9       2013-01-01 06:00:00        NaN                      NaN
# 10      2013-01-01 06:00:00     2011.0  Fixed wing multi engine
# 11      2013-01-01 06:00:00     2007.0  Fixed wing multi engine
# 12      2013-01-01 06:00:00     1998.0  Fixed wing multi engine
# 13      2013-01-01 06:00:00        NaN  Fixed wing multi engine
# 14      2013-01-01 06:00:00        NaN                      NaN
# 15      2013-01-01 05:00:00     2008.0  Fixed wing multi engine
# 16      2013-01-01 06:00:00     2008.0  Fixed wing multi engine
# 17      2013-01-01 06:00:00     2004.0  Fixed wing multi engine
# 18      2013-01-01 06:00:00        NaN                      NaN
# 19      2013-01-01 06:00:00     2006.0  Fixed wing multi engine
# 20      2013-01-01 06:00:00     1991.0  Fixed wing multi engine
# 21      2013-01-01 06:00:00        NaN                      NaN
# 22      2013-01-01 06:00:00     1990.0  Fixed wing multi engine
# 23      2013-01-01 06:00:00     2000.0  Fixed wing multi engine
# 24      2013-01-01 06:00:00     2009.0  Fixed wing multi engine
# 25      2013-01-01 06:00:00        NaN                      NaN
# 26      2013-01-01 06:00:00        NaN                      NaN
# 27      2013-01-01 06:00:00     2006.0  Fixed wing multi engine
# 28      2013-01-01 06:00:00     2011.0  Fixed wing multi engine
# 29      2013-01-01 06:00:00     2001.0  Fixed wing multi engine
# ...                     ...        ...                      ...
# 336746  2013-09-30 21:00:00     2002.0  Fixed wing multi engine
# 336747  2013-09-30 21:00:00     2002.0  Fixed wing multi engine
# 336748  2013-09-30 21:00:00     2012.0  Fixed wing multi engine
# 336749  2013-09-30 20:00:00     2004.0  Fixed wing multi engine
# 336750  2013-09-30 21:00:00        NaN                      NaN
# 336751  2013-09-30 21:00:00     1987.0  Fixed wing multi engine
# 336752  2013-09-30 21:00:00     1998.0  Fixed wing multi engine
# 336753  2013-09-30 21:00:00     2006.0  Fixed wing multi engine
# 336754  2013-09-30 21:00:00     2005.0  Fixed wing multi engine
# 336755  2013-09-30 21:00:00     1998.0  Fixed wing multi engine
# 336756  2013-09-30 21:00:00     2002.0  Fixed wing multi engine
# 336757  2013-09-30 18:00:00     2007.0  Fixed wing multi engine
# 336758  2013-09-30 22:00:00     2003.0  Fixed wing multi engine
# 336759  2013-09-30 21:00:00        NaN                      NaN
# 336760  2013-09-30 20:00:00     2003.0  Fixed wing multi engine
# 336761  2013-09-30 22:00:00     2005.0  Fixed wing multi engine
# 336762  2013-09-30 21:00:00     1993.0  Fixed wing multi engine
# 336763  2013-09-30 20:00:00     2012.0  Fixed wing multi engine
# 336764  2013-09-30 22:00:00     2010.0  Fixed wing multi engine
# 336765  2013-09-30 22:00:00     2013.0  Fixed wing multi engine
# 336766  2013-09-30 22:00:00     2007.0  Fixed wing multi engine
# 336767  2013-09-30 22:00:00     2011.0  Fixed wing multi engine
# 336768  2013-09-30 22:00:00     2003.0  Fixed wing multi engine
# 336769  2013-09-30 23:00:00     2000.0  Fixed wing multi engine
# 336770  2013-09-30 18:00:00     2004.0  Fixed wing multi engine
# 336771  2013-09-30 14:00:00        NaN                      NaN
# 336772  2013-09-30 22:00:00        NaN                      NaN
# 336773  2013-09-30 12:00:00        NaN                      NaN
# 336774  2013-09-30 11:00:00        NaN                      NaN
# 336775  2013-09-30 08:00:00        NaN                      NaN
#
#                          manufacturer            model  engines  seats speed  \
# 0                              BOEING          737-824      2.0  149.0   NaN
# 1                              BOEING          737-824      2.0  149.0   NaN
# 2                              BOEING          757-223      2.0  178.0   NaN
# 3                              AIRBUS         A320-232      2.0  200.0   NaN
# 4                              BOEING          757-232      2.0  178.0   NaN
# 5                              BOEING        737-924ER      2.0  191.0   NaN
# 6                    AIRBUS INDUSTRIE         A320-232      2.0  200.0   NaN
# 7                            CANADAIR      CL-600-2B19      2.0   55.0   NaN
# 8                              AIRBUS         A320-232      2.0  200.0   NaN
# 9                                 NaN              NaN      NaN    NaN   NaN
# 10                             AIRBUS         A320-232      2.0  200.0   NaN
# 11                             AIRBUS         A320-232      2.0  200.0   NaN
# 12                             BOEING          757-224      2.0  178.0   NaN
# 13                             BOEING        737-924ER      2.0  191.0   NaN
# 14                                NaN              NaN      NaN    NaN   NaN
# 15                             AIRBUS         A320-232      2.0  200.0   NaN
# 16                             BOEING          737-824      2.0  149.0   NaN
# 17                             AIRBUS         A320-232      2.0  200.0   NaN
# 18                                NaN              NaN      NaN    NaN   NaN
# 19                             AIRBUS         A320-232      2.0  200.0   NaN
# 20      MCDONNELL DOUGLAS AIRCRAFT CO            MD-88      2.0  142.0   NaN
# 21                                NaN              NaN      NaN    NaN   NaN
# 22                             BOEING          757-223      2.0  178.0   NaN
# 23                             BOEING          737-832      2.0  189.0   NaN
# 24                             BOEING        737-924ER      2.0  191.0   NaN
# 25                                NaN              NaN      NaN    NaN   NaN
# 26                                NaN              NaN      NaN    NaN   NaN
# 27                             AIRBUS         A320-232      2.0  200.0   NaN
# 28                             AIRBUS         A320-232      2.0  200.0   NaN
# 29                   AIRBUS INDUSTRIE         A319-114      2.0  145.0   NaN
# ...                               ...              ...      ...    ...   ...
# 336746                 BOMBARDIER INC      CL-600-2C10      2.0   80.0   NaN
# 336747                        EMBRAER        EMB-145LR      2.0   55.0   NaN
# 336748                         AIRBUS         A320-232      2.0  200.0   NaN
# 336749                 BOMBARDIER INC      CL-600-2C10      2.0   80.0   NaN
# 336750                            NaN              NaN      NaN    NaN   NaN
# 336751                         BOEING          767-223      2.0  255.0   NaN
# 336752                        EMBRAER        EMB-145LR      2.0   55.0   NaN
# 336753                         AIRBUS         A320-232      2.0  200.0   NaN
# 336754                         AIRBUS         A320-232      2.0  200.0   NaN
# 336755               AIRBUS INDUSTRIE         A319-131      2.0  179.0   NaN
# 336756                        EMBRAER        EMB-145LR      2.0   55.0   NaN
# 336757                 BOMBARDIER INC      CL-600-2D24      2.0   95.0   NaN
# 336758                 BOMBARDIER INC      CL-600-2C10      2.0   80.0   NaN
# 336759                            NaN              NaN      NaN    NaN   NaN
# 336760                        EMBRAER        EMB-145XR      2.0   55.0   NaN
# 336761                        EMBRAER  ERJ 190-100 IGW      2.0   20.0   NaN
# 336762                         BOEING          757-222      2.0  178.0   NaN
# 336763                         AIRBUS         A320-232      2.0  200.0   NaN
# 336764                        EMBRAER  ERJ 190-100 IGW      2.0   20.0   NaN
# 336765                        EMBRAER  ERJ 190-100 IGW      2.0   20.0   NaN
# 336766                        EMBRAER  ERJ 190-100 IGW      2.0   20.0   NaN
# 336767                        EMBRAER  ERJ 190-100 IGW      2.0   20.0   NaN
# 336768                         AIRBUS         A320-232      2.0  200.0   NaN
# 336769               AIRBUS INDUSTRIE         A320-232      2.0  200.0   NaN
# 336770                 BOMBARDIER INC      CL-600-2C10      2.0   80.0   NaN
# 336771                            NaN              NaN      NaN    NaN   NaN
# 336772                            NaN              NaN      NaN    NaN   NaN
# 336773                            NaN              NaN      NaN    NaN   NaN
# 336774                            NaN              NaN      NaN    NaN   NaN
# 336775                            NaN              NaN      NaN    NaN   NaN
#
#            engine
# 0       Turbo-fan
# 1       Turbo-fan
# 2       Turbo-fan
# 3       Turbo-fan
# 4       Turbo-fan
# 5       Turbo-fan
# 6       Turbo-fan
# 7       Turbo-fan
# 8       Turbo-fan
# 9             NaN
# 10      Turbo-fan
# 11      Turbo-fan
# 12      Turbo-jet
# 13      Turbo-fan
# 14            NaN
# 15      Turbo-fan
# 16      Turbo-fan
# 17      Turbo-fan
# 18            NaN
# 19      Turbo-fan
# 20      Turbo-fan
# 21            NaN
# 22      Turbo-fan
# 23      Turbo-jet
# 24      Turbo-fan
# 25            NaN
# 26            NaN
# 27      Turbo-fan
# 28      Turbo-fan
# 29      Turbo-fan
# ...           ...
# 336746  Turbo-fan
# 336747  Turbo-fan
# 336748  Turbo-fan
# 336749  Turbo-fan
# 336750        NaN
# 336751  Turbo-fan
# 336752  Turbo-fan
# 336753  Turbo-fan
# 336754  Turbo-fan
# 336755  Turbo-jet
# 336756  Turbo-fan
# 336757  Turbo-fan
# 336758  Turbo-fan
# 336759        NaN
# 336760  Turbo-fan
# 336761  Turbo-fan
# 336762  Turbo-jet
# 336763  Turbo-fan
# 336764  Turbo-fan
# 336765  Turbo-fan
# 336766  Turbo-fan
# 336767  Turbo-fan
# 336768  Turbo-fan
# 336769  Turbo-fan
# 336770  Turbo-fan
# 336771        NaN
# 336772        NaN
# 336773        NaN
# 336774        NaN
# 336775        NaN
#
# [336776 rows x 27 columns]

# %%
pd.read_sql_query('''
SELECT planes.*, airlines.* FROM
   (SELECT DISTINCT carrier, tailnum FROM flights) AS cartail
  INNER JOIN planes ON cartail.tailnum=planes.tailnum
  INNER JOIN airlines ON cartail.carrier=airlines.carrier
''', conn).head(5)
# Out:
#    index tailnum    year                     type      manufacturer  \
# 0      0  N10156  2004.0  Fixed wing multi engine           EMBRAER
# 1      1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 2      2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 3      3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE
# 4      4  N10575  2002.0  Fixed wing multi engine           EMBRAER
#
#        model  engines  seats  speed     engine  index carrier  \
# 0  EMB-145XR        2     55    NaN  Turbo-fan      5      EV
# 1   A320-214        2    182    NaN  Turbo-fan     12      US
# 2   A320-214        2    182    NaN  Turbo-fan     12      US
# 3   A320-214        2    182    NaN  Turbo-fan     12      US
# 4  EMB-145LR        2     55    NaN  Turbo-fan      5      EV
#
#                        name
# 0  ExpressJet Airlines Inc.
# 1           US Airways Inc.
# 2           US Airways Inc.
# 3           US Airways Inc.
# 4  ExpressJet Airlines Inc.

# %%
cartail = flights.drop_duplicates(['carrier','tailnum']).loc[:,['tailnum','carrier']]
(
    cartail.join(planes.set_index('tailnum'), on='tailnum', lsuffix='_left', rsuffix='_right')
    .join(airlines.set_index('carrier'), on='carrier', lsuffix='_l', rsuffix='_r')
    .reset_index().head()
)
# Out:
#    index tailnum carrier    year                     type manufacturer  \
# 0      0  N14228      UA  1999.0  Fixed wing multi engine       BOEING
# 1      1  N24211      UA  1998.0  Fixed wing multi engine       BOEING
# 2      2  N619AA      AA  1990.0  Fixed wing multi engine       BOEING
# 3      3  N804JB      B6  2012.0  Fixed wing multi engine       AIRBUS
# 4      4  N668DN      DL  1991.0  Fixed wing multi engine       BOEING
#
#       model  engines  seats  speed     engine                    name
# 0   737-824      2.0  149.0    NaN  Turbo-fan   United Air Lines Inc.
# 1   737-824      2.0  149.0    NaN  Turbo-fan   United Air Lines Inc.
# 2   757-223      2.0  178.0    NaN  Turbo-fan  American Airlines Inc.
# 3  A320-232      2.0  200.0    NaN  Turbo-fan         JetBlue Airways
# 4   757-232      2.0  178.0    NaN  Turbo-fan    Delta Air Lines Inc.

# %%
(
    flights.loc[:,['carrier','tailnum']].drop_duplicates().merge(airlines, on='carrier', how='inner')
    .merge(planes, on='tailnum', how='inner').head(5)
)
# Out:
#   carrier tailnum                   name    year                     type  \
# 0      UA  N14228  United Air Lines Inc.  1999.0  Fixed wing multi engine
# 1      UA  N24211  United Air Lines Inc.  1998.0  Fixed wing multi engine
# 2      UA  N39463  United Air Lines Inc.  2012.0  Fixed wing multi engine
# 3      UA  N29129  United Air Lines Inc.  1998.0  Fixed wing multi engine
# 4      UA  N53441  United Air Lines Inc.     NaN  Fixed wing multi engine
#
#   manufacturer      model  engines  seats  speed     engine
# 0       BOEING    737-824        2    149    NaN  Turbo-fan
# 1       BOEING    737-824        2    149    NaN  Turbo-fan
# 2       BOEING  737-924ER        2    191    NaN  Turbo-fan
# 3       BOEING    757-224        2    178    NaN  Turbo-jet
# 4       BOEING  737-924ER        2    191    NaN  Turbo-fan

# %%
pd.read_sql_query('''
SELECT flights2.*, weather2.atemp, weather2.ahumid, weather2.apressure FROM
     (SELECT * FROM flights WHERE origin='EWR') AS flights2
  LEFT JOIN
     (SELECT year, month, day, AVG(temp) AS atemp,
       AVG(humid) AS ahumid, AVG(pressure) AS apressure
      FROM weather WHERE origin='EWR' GROUP BY year, month, day) AS weather2
  ON flights2.year=weather2.year
    AND flights2.month=weather2.month
    AND flights2.day=weather2.day
''', conn).head(1)
# Out:
#    index  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0      0  2013      1    1     517.0             515        2.0     830.0
#
#    sched_arr_time  arr_delay     ...      origin  dest air_time distance hour  \
# 0             819       11.0     ...         EWR   IAH    227.0     1400    5
#
#    minute            time_hour  atemp     ahumid    apressure
# 0      15  2013-01-01 05:00:00  38.48  58.386087  1012.442857
#
# [1 rows x 23 columns]

# %%
flights2 = flights.query('origin == "EWR"')
flights2 = flights2.set_index(['year', 'month', 'day'])
flights2
# Out:
#                 dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# year month day
# 2013 1     1       517.0             515        2.0     830.0             819
#            1       554.0             558       -4.0     740.0             728
#            1       555.0             600       -5.0     913.0             854
#            1       558.0             600       -2.0     923.0             937
#            1       559.0             600       -1.0     854.0             902
#            1       601.0             600        1.0     844.0             850
#            1       606.0             610       -4.0     858.0             910
#            1       607.0             607        0.0     858.0             915
#            1       608.0             600        8.0     807.0             735
#            1       615.0             615        0.0     833.0             842
#            1       622.0             630       -8.0    1017.0            1014
#            1       624.0             630       -6.0     909.0             840
#            1       628.0             630       -2.0    1016.0             947
#            1       629.0             630       -1.0     824.0             833
#            1       632.0             608       24.0     740.0             728
#            1       643.0             646       -3.0     922.0             940
#            1       643.0             645       -2.0     837.0             848
#            1       644.0             636        8.0     931.0             940
#            1       646.0             645        1.0    1023.0            1030
#            1       656.0             700       -4.0     948.0            1011
#            1       659.0             700       -1.0     959.0            1008
#            1       701.0             700        1.0    1123.0            1154
#            1       715.0             713        2.0     911.0             850
#            1       723.0             725       -2.0    1013.0            1017
#            1       724.0             725       -1.0    1020.0            1030
#            1       725.0             730       -5.0    1052.0            1040
#            1       727.0             730       -3.0     959.0             952
#            1       732.0             645       47.0    1011.0             941
#            1       739.0             739        0.0    1104.0            1038
#            1       746.0             746        0.0    1119.0            1129
# ...                  ...             ...        ...       ...             ...
#      9     30     2010.0            2016       -6.0    2119.0            2128
#            30     2015.0            2015        0.0    2244.0            2307
#            30     2019.0            2023       -4.0    2225.0            2240
#            30     2021.0            2022       -1.0    2144.0            2200
#            30     2026.0            2028       -2.0    2317.0            2340
#            30     2030.0            2045      -15.0    2141.0            2153
#            30     2030.0            2035       -5.0    2324.0            2340
#            30     2033.0            2030        3.0    2143.0            2150
#            30     2034.0            2040       -6.0    2227.0            2248
#            30     2035.0            2029        6.0    2318.0            2337
#            30     2047.0            2059      -12.0    2222.0            2255
#            30     2052.0            2059       -7.0    2315.0            2358
#            30     2053.0            1815      158.0    2310.0            2054
#            30     2054.0            2056       -2.0    2249.0            2316
#            30     2055.0            2059       -4.0    2158.0            2211
#            30     2058.0            2105       -7.0    2217.0            2226
#            30     2059.0            2003       56.0    2311.0            2237
#            30     2104.0            2019       45.0    2304.0            2240
#            30     2104.0            2110       -6.0    2323.0            2341
#            30     2105.0            2106       -1.0    2329.0            2354
#            30     2114.0            2025       49.0    2304.0            2228
#            30     2116.0            2124       -8.0    2317.0            2337
#            30     2119.0            2005       74.0    2310.0            2212
#            30     2122.0            2127       -5.0    2226.0            2237
#            30     2127.0            2129       -2.0    2314.0            2323
#            30     2142.0            2129       13.0    2250.0            2239
#            30     2149.0            2156       -7.0    2245.0            2308
#            30     2150.0            2159       -9.0    2250.0            2306
#            30     2211.0            2059       72.0    2339.0            2242
#            30     2233.0            2113       80.0     112.0              30
#
#                 arr_delay carrier  flight tailnum origin dest  air_time  \
# year month day
# 2013 1     1         11.0      UA    1545  N14228    EWR  IAH     227.0
#            1         12.0      UA    1696  N39463    EWR  ORD     150.0
#            1         19.0      B6     507  N516JB    EWR  FLL     158.0
#            1        -14.0      UA    1124  N53441    EWR  SFO     361.0
#            1         -8.0      UA    1187  N76515    EWR  LAS     337.0
#            1         -6.0      B6     343  N644JB    EWR  PBI     147.0
#            1        -12.0      AA    1895  N633AA    EWR  MIA     152.0
#            1        -17.0      UA    1077  N53442    EWR  MIA     157.0
#            1         32.0      MQ    3768  N9EAMQ    EWR  ORD     139.0
#            1         -9.0      DL     575  N326NB    EWR  ATL     120.0
#            1          3.0      US     245  N807AW    EWR  PHX     342.0
#            1         29.0      EV    4626  N11107    EWR  MSP     190.0
#            1         29.0      UA    1665  N33289    EWR  LAX     366.0
#            1         -9.0      US    1019  N426US    EWR  CLT      91.0
#            1         12.0      EV    4144  N13553    EWR  IAD      52.0
#            1        -18.0      UA     556  N497UA    EWR  PBI     146.0
#            1        -11.0      US     926  N178US    EWR  CLT      91.0
#            1         -9.0      UA    1701  N75435    EWR  FLL     151.0
#            1         -7.0      UA    1496  N38727    EWR  SNA     380.0
#            1        -23.0      UA    1115  N24212    EWR  TPA     156.0
#            1         -9.0      UA     960  N838UA    EWR  RSW     164.0
#            1        -31.0      UA    1203  N77296    EWR  SJU     188.0
#            1         21.0      UA     544  N841UA    EWR  ORD     156.0
#            1         -4.0      UA     962  N514UA    EWR  PBI     153.0
#            1        -10.0      AS      11  N594AS    EWR  SEA     338.0
#            1         12.0      AA    2083  N4WRAA    EWR  DFW     238.0
#            1          7.0      UA    1162  N37462    EWR  DEN     254.0
#            1         30.0      UA    1111  N37456    EWR  MCO     145.0
#            1         26.0      UA    1479  N37408    EWR  IAH     249.0
#            1        -10.0      UA    1668  N24224    EWR  SFO     373.0
# ...                   ...     ...     ...     ...    ...  ...       ...
#      9     30        -9.0      EV    4312  N13969    EWR  DCA      35.0
#            30       -23.0      UA    1545  N17730    EWR  IAH     174.0
#            30       -15.0      EV    4085  N14188    EWR  OMA     149.0
#            30       -16.0      UA    1464  N76503    EWR  CLE      54.0
#            30       -23.0      UA    1680  N31412    EWR  MIA     141.0
#            30       -12.0      B6    2680  N266JB    EWR  BOS      38.0
#            30       -16.0      UA     374  N484UA    EWR  FLL     141.0
#            30        -7.0      WN    2520  N286WN    EWR  MDW      97.0
#            30       -21.0      EV    4536  N25134    EWR  CVG      80.0
#            30       -19.0      UA    1039  N78524    EWR  AUS     191.0
#            30       -33.0      EV    4368  N41104    EWR  DAY      75.0
#            30       -43.0      UA    1416  N68453    EWR  MCO     123.0
#            30       136.0      EV    5292  N600QX    EWR  ATL      91.0
#            30       -27.0      EV    4397  N17146    EWR  MSY     142.0
#            30       -13.0      UA    1066  N16701    EWR  BOS      40.0
#            30        -9.0      EV    5815  N13978    EWR  RIC      51.0
#            30        34.0      EV    4204  N11127    EWR  OKC     166.0
#            30        24.0      EV    4333  N11109    EWR  TUL     154.0
#            30       -18.0      EV    5811  N17560    EWR  JAX     112.0
#            30       -25.0      UA     475  N477UA    EWR  IAH     175.0
#            30        36.0      EV    4348  N11184    EWR  MSP     145.0
#            30       -20.0      EV    4682  N14542    EWR  SDF      94.0
#            30        58.0      EV    4321  N17984    EWR  MCI     147.0
#            30       -11.0      EV    4372  N14902    EWR  DCA      35.0
#            30        -9.0      EV    3833  N16546    EWR  CLT      72.0
#            30        11.0      EV    4509  N12957    EWR  PWM      47.0
#            30       -23.0      UA     523  N813UA    EWR  BOS      37.0
#            30       -16.0      EV    3842  N10575    EWR  MHT      39.0
#            30        57.0      EV    4672  N12145    EWR  STL     120.0
#            30        42.0      UA     471  N578UA    EWR  SFO     318.0
#
#                 distance  hour  minute            time_hour
# year month day
# 2013 1     1        1400     5      15  2013-01-01 05:00:00
#            1         719     5      58  2013-01-01 05:00:00
#            1        1065     6       0  2013-01-01 06:00:00
#            1        2565     6       0  2013-01-01 06:00:00
#            1        2227     6       0  2013-01-01 06:00:00
#            1        1023     6       0  2013-01-01 06:00:00
#            1        1085     6      10  2013-01-01 06:00:00
#            1        1085     6       7  2013-01-01 06:00:00
#            1         719     6       0  2013-01-01 06:00:00
#            1         746     6      15  2013-01-01 06:00:00
#            1        2133     6      30  2013-01-01 06:00:00
#            1        1008     6      30  2013-01-01 06:00:00
#            1        2454     6      30  2013-01-01 06:00:00
#            1         529     6      30  2013-01-01 06:00:00
#            1         212     6       8  2013-01-01 06:00:00
#            1        1023     6      46  2013-01-01 06:00:00
#            1         529     6      45  2013-01-01 06:00:00
#            1        1065     6      36  2013-01-01 06:00:00
#            1        2434     6      45  2013-01-01 06:00:00
#            1         997     7       0  2013-01-01 07:00:00
#            1        1068     7       0  2013-01-01 07:00:00
#            1        1608     7       0  2013-01-01 07:00:00
#            1         719     7      13  2013-01-01 07:00:00
#            1        1023     7      25  2013-01-01 07:00:00
#            1        2402     7      25  2013-01-01 07:00:00
#            1        1372     7      30  2013-01-01 07:00:00
#            1        1605     7      30  2013-01-01 07:00:00
#            1         937     6      45  2013-01-01 06:00:00
#            1        1400     7      39  2013-01-01 07:00:00
#            1        2565     7      46  2013-01-01 07:00:00
# ...                  ...   ...     ...                  ...
#      9     30        199    20      16  2013-09-30 20:00:00
#            30       1400    20      15  2013-09-30 20:00:00
#            30       1134    20      23  2013-09-30 20:00:00
#            30        404    20      22  2013-09-30 20:00:00
#            30       1085    20      28  2013-09-30 20:00:00
#            30        200    20      45  2013-09-30 20:00:00
#            30       1065    20      35  2013-09-30 20:00:00
#            30        711    20      30  2013-09-30 20:00:00
#            30        569    20      40  2013-09-30 20:00:00
#            30       1504    20      29  2013-09-30 20:00:00
#            30        533    20      59  2013-09-30 20:00:00
#            30        937    20      59  2013-09-30 20:00:00
#            30        746    18      15  2013-09-30 18:00:00
#            30       1167    20      56  2013-09-30 20:00:00
#            30        200    20      59  2013-09-30 20:00:00
#            30        277    21       5  2013-09-30 21:00:00
#            30       1325    20       3  2013-09-30 20:00:00
#            30       1215    20      19  2013-09-30 20:00:00
#            30        820    21      10  2013-09-30 21:00:00
#            30       1400    21       6  2013-09-30 21:00:00
#            30       1008    20      25  2013-09-30 20:00:00
#            30        642    21      24  2013-09-30 21:00:00
#            30       1092    20       5  2013-09-30 20:00:00
#            30        199    21      27  2013-09-30 21:00:00
#            30        529    21      29  2013-09-30 21:00:00
#            30        284    21      29  2013-09-30 21:00:00
#            30        200    21      56  2013-09-30 21:00:00
#            30        209    21      59  2013-09-30 21:00:00
#            30        872    20      59  2013-09-30 20:00:00
#            30       2565    21      13  2013-09-30 21:00:00
#
# [120835 rows x 16 columns]

# %%
flights2 = flights.query('origin == "EWR"').set_index(['year', 'month', 'day'])
weather2 = weather.query('origin == "EWR"').groupby(['year','month','day'])[['temp','humid','pressure']].mean()
weather2 = weather2.rename(index=str, columns={"temp": "atemp", "humid": "ahumid", "pressure": "apressure"})
flights2.merge(weather2, how='inner')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-291-f441f4341d98> in <module>
#       2 weather2 = weather.query('origin == "EWR"').groupby(['year','month','day'])[['temp','humid','pressure']].mean()
#       3 weather2 = weather2.rename(index=str, columns={"temp": "atemp", "humid": "ahumid", "pressure": "apressure"})
# ----> 4 flights2.merge(weather2, how='inner')
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     544             warnings.warn(msg, UserWarning)
#     545
# --> 546         self._validate_specification()
#     547
#     548         # note this function has side effects
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1033                         'left_index={lidx}, right_index={ridx}'
#    1034                         .format(lon=self.left_on, ron=self.right_on,
# -> 1035                                 lidx=self.left_index, ridx=self.right_index))
#    1036                 if not common_cols.is_unique:
#    1037                     raise MergeError("Data columns not unique: {common!r}"
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
flights2 = flights.query('origin == "EWR"').set_index(['year', 'month', 'day'])
weather2 = weather.query('origin == "EWR"').groupby(['year','month','day'])[['temp','humid','pressure']].mean()
weather2 = weather2.rename(index=str, columns={"temp": "atemp", "humid": "ahumid", "pressure": "apressure"}).reset_index()
flights2.merge(weather2, how='inner')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-289-3baa653211e0> in <module>
#       2 weather2 = weather.query('origin == "EWR"').groupby(['year','month','day'])[['temp','humid','pressure']].mean()
#       3 weather2 = weather2.rename(index=str, columns={"temp": "atemp", "humid": "ahumid", "pressure": "apressure"}).reset_index()
# ----> 4 flights2.merge(weather2, how='inner')
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    6387                      right_on=right_on, left_index=left_index,
#    6388                      right_index=right_index, sort=sort, suffixes=suffixes,
# -> 6389                      copy=copy, indicator=indicator, validate=validate)
#    6390
#    6391     def round(self, decimals=0, *args, **kwargs):
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     544             warnings.warn(msg, UserWarning)
#     545
# --> 546         self._validate_specification()
#     547
#     548         # note this function has side effects
#
# ~/Documents/DSR/env/lib/python3.7/site-packages/pandas/core/reshape/merge.py in _validate_specification(self)
#    1033                         'left_index={lidx}, right_index={ridx}'
#    1034                         .format(lon=self.left_on, ron=self.right_on,
# -> 1035                                 lidx=self.left_index, ridx=self.right_index))
#    1036                 if not common_cols.is_unique:
#    1037                     raise MergeError("Data columns not unique: {common!r}"
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False
