# %%
import pyspark
sc = pyspark.SparkContext('local[*]')

# %%
# load text of macbeth from s3
# !wget https://dsr-notebooks.s3.amazonaws.com/macbeth.txt
shakespeare = sc.textFile("macbeth.txt")
# Out:
# --2019-03-15 09:02:18--  https://dsr-notebooks.s3.amazonaws.com/macbeth.txt
# Resolving dsr-notebooks.s3.amazonaws.com (dsr-notebooks.s3.amazonaws.com)... 52.216.80.168
# Connecting to dsr-notebooks.s3.amazonaws.com (dsr-notebooks.s3.amazonaws.com)|52.216.80.168|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5589889 (5.3M) [text/plain]
# Saving to: ‘macbeth.txt’
#
# macbeth.txt         100%[===================>]   5.33M  3.08MB/s    in 1.7s
#
# 2019-03-15 09:02:21 (3.08 MB/s) - ‘macbeth.txt’ saved [5589889/5589889]

# %%
lines = shakespeare.map(lambda line: line.lower())

# %%
lines.cache()
# Out:
# PythonRDD[2] at RDD at PythonRDD.scala:48

# %%
macbeth = lines.filter(lambda l: l.find("macbeth") >= 0)
import sys
print(macbeth)
# Out:
# PythonRDD[3] at RDD at PythonRDD.scala:48

# %%
macbeth.count()
# Out:
# 283

# %%
macbeth.take(5)
# Out:
# ['the tragedy of macbeth',
#  "  macbeth, thane of glamis and cawdor, a general in the king's army",
#  '  lady macbeth, his wife',
#  '  seyton, attendant to macbeth',
#  '  gentlewoman attending on lady macbeth']

# %%
macbeth_and_macduff = macbeth.filter(lambda l: l.find("macduff") >= 0)

# %%
print(macbeth_and_macduff)
macbeth_and_macduff.collect()
# Out:
# PythonRDD[7] at RDD at PythonRDD.scala:48
# ['  macduff. those that macbeth hath slain.',
#  "  macbeth. how say'st thou, that macduff denies his person",
#  '  first apparition. macbeth! macbeth! macbeth! beware macduff,',
#  '  macbeth. then live, macduff. what need i fear of thee?',
#  "             re-enter macduff, with macbeth's head."]

# %%
print(macbeth_and_macduff.toDebugString())
# Out:
# b'(2) PythonRDD[7] at RDD at PythonRDD.scala:48 []\n |  PythonRDD[2] at RDD at PythonRDD.scala:48 []\n |      CachedPartitions: 2; MemorySize: 4.0 MB; ExternalBlockStoreSize: 0.0 B; DiskSize: 0.0 B\n |  macbeth.txt MapPartitionsRDD[1] at textFile at NativeMethodAccessorImpl.java:0 []\n |  macbeth.txt HadoopRDD[0] at textFile at NativeMethodAccessorImpl.java:0 []'

# %%
import re
words = lines.flatMap(lambda l: re.split(r'\W+', l))

# %%
groupedWords = words.map(lambda w: (w, 1))
unsorted = groupedWords.reduceByKey(lambda a, b: a + b)
unsorted.collect()
# Out:
# [('project', 331),
#  ('gutenberg', 326),
#  ('ebook', 17),
#  ('of', 18307),
#  ('shakespeare', 272),
#  ('', 197060),
#  ('this', 6900),
#  ('is', 9808),
#  ('use', 562),
#  ('anyone', 7),
#  ('anywhere', 8),
#  ('at', 2536),
#  ('no', 3814),
#  ('restrictions', 2),
#  ('whatsoever', 17),
#  ('may', 1891),
#  ('give', 1353),
#  ('away', 864),
#  ('online', 4),
#  ('www', 11),
#  ('org', 17),
#  ('details', 1),
#  ('below', 58),
#  ('copyright', 244),
#  ('guidelines', 1),
#  ('in', 11183),
#  ('title', 92),
#  ('posting', 5),
#  ('1', 357),
#  ('2011', 1),
#  ('100', 5),
#  ('january', 3),
#  ('1994', 1),
#  ('language', 37),
#  ('start', 37),
#  ('produced', 4),
#  ('world', 904),
#  ('library', 233),
#  ('inc', 224),
#  ('presented', 18),
#  ('cooperation', 1),
#  ('cdroms', 1),
#  ('are', 3917),
#  ('placed', 11),
#  ('public', 66),
#  ('domain', 12),
#  ('certain', 178),
#  ('implications', 1),
#  ('read', 210),
#  ('version', 222),
#  ('1990', 221),
#  ('1993', 221),
#  ('college', 225),
#  ('machine', 224),
#  ('long', 704),
#  ('as', 5988),
#  ('others', 422),
#  ('only', 535),
#  ('used', 246),
#  ('prohibited', 221),
#  ('commercial', 222),
#  ('distribution', 230),
#  ('service', 445),
#  ('charges', 238),
#  ('presentation', 4),
#  ('however', 14),
#  ('neither', 186),
#  ('shareware', 1),
#  ('nor', 971),
#  ('conditions', 29),
#  ('material', 6),
#  ('encouraged', 3),
#  ('like', 1787),
#  ('but', 6287),
#  ('print', 23),
#  ('other', 724),
#  ('tm', 59),
#  ('protected', 4),
#  ('effect', 72),
#  ('s', 7734),
#  ('right', 356),
#  ('limited', 13),
#  ('statement', 3),
#  ('b', 16),
#  ('subject', 106),
#  ('honor', 42),
#  ('refund', 13),
#  ('compressed', 3),
#  ('proprietary', 2),
#  ('form', 121),
#  ('resulting', 1),
#  ('when', 2056),
#  ('displayed', 3),
#  ('characters', 13),
#  ('than', 1885),
#  ('work', 245),
#  ('although', 79),
#  ('asterisk', 1),
#  ('underline', 1),
#  ('_', 1),
#  ('convey', 50),
#  ('punctuation', 1),
#  ('additional', 6),
#  ('indicate', 2),
#  ('links', 6),
#  ('convertible', 1),
#  ('expense', 20),
#  ('into', 644),
#  ('ascii', 5),
#  ('ebcdic', 1),
#  ('provide', 39),
#  ('fee', 44),
#  ('incomplete', 2),
#  ('inaccurate', 2),
#  ('corrupt', 31),
#  ('transcription', 2),
#  ('errors', 15),
#  ('disk', 2),
#  ('damage', 6),
#  ('cannot', 766),
#  ('equipment', 4),
#  ('liability', 5),
#  ('expenses', 5),
#  ('legal', 5),
#  ('fees', 10),
#  ('have', 5910),
#  ('remedies', 10),
#  ('negligence', 16),
#  ('breach', 37),
#  ('contract', 29),
#  ('indirect', 10),
#  ('consequential', 2),
#  ('punitive', 2),
#  ('incidental', 2),
#  ('even', 575),
#  ('possibility', 5),
#  ('discover', 44),
#  ('days', 213),
#  ('receiv', 61),
#  ('money', 190),
#  ('paid', 72),
#  ('an', 1896),
#  ('explanatory', 1),
#  ('person', 156),
#  ('medium', 7),
#  ('must', 1502),
#  ('alternatively', 2),
#  ('electronically', 4),
#  ('opportunity', 17),
#  ('kind', 283),
#  ('implied', 4),
#  ('particular', 60),
#  ('do', 3847),
#  ('allow', 49),
#  ('disclaimers', 3),
#  ('consequen', 1),
#  ('tial', 1),
#  ('above', 147),
#  ('exclusions', 1),
#  ('indemnify', 2),
#  ('officers', 88),
#  ('members', 11),
#  ('bility', 1),
#  ('arise', 39),
#  ('indirectly', 10),
#  ('following', 56),
#  ('cause', 340),
#  ('alteration', 11),
#  ('modification', 2),
#  ('c', 30),
#  ('4', 38),
#  ('send', 262),
#  ('don', 49),
#  ('dedicated', 4),
#  ('freely', 59),
#  ('gratefully', 2),
#  ('accepts', 3),
#  ('scanning', 1),
#  ('free', 195),
#  ('think', 1074),
#  ('ject', 1),
#  ('attorney', 9),
#  ('internet', 1),
#  ('72600', 1),
#  ('2026', 1),
#  ('tel', 1),
#  ('__', 1),
#  ('12', 2),
#  ('93', 3),
#  ('fairest', 42),
#  ('creatures', 38),
#  ('we', 3623),
#  ('increase', 28),
#  ('thereby', 26),
#  ('beauty', 233),
#  ('rose', 68),
#  ('never', 1020),
#  ('die', 475),
#  ('riper', 3),
#  ('his', 6859),
#  ('tender', 149),
#  ('heir', 109),
#  ('bear', 553),
#  ('thou', 5549),
#  ('thine', 457),
#  ('own', 772),
#  ('bright', 72),
#  ('eyes', 685),
#  ('feed', 83),
#  ('st', 1065),
#  ('thy', 4034),
#  ('flame', 25),
#  ('self', 212),
#  ('substantial', 5),
#  ('fuel', 5),
#  ('making', 83),
#  ('famine', 12),
#  ('where', 1350),
#  ('abundance', 13),
#  ('sweet', 807),
#  ('now', 2792),
#  ('ornament', 18),
#  ('herald', 60),
#  ('churl', 9),
#  ('mak', 22),
#  ('pity', 221),
#  ('due', 77),
#  ('grave', 184),
#  ('forty', 30),
#  ('winters', 10),
#  ('besiege', 10),
#  ('brow', 73),
#  ('dig', 11),
#  ('field', 192),
#  ('weed', 18),
#  ('worth', 205),
#  ('treasure', 53),
#  ('say', 1758),
#  ('eating', 14),
#  ('praise', 182),
#  ('more', 2293),
#  ('couldst', 27),
#  ('child', 242),
#  ('sum', 56),
#  ('count', 132),
#  ('make', 1640),
#  ('excuse', 78),
#  ('proving', 1),
#  ('succession', 17),
#  ('new', 276),
#  ('feel', 108),
#  ('cold', 202),
#  ('look', 938),
#  ('glass', 68),
#  ('tell', 1083),
#  ('viewest', 2),
#  ('whose', 618),
#  ('repair', 46),
#  ('dost', 429),
#  ('beguile', 24),
#  ('unbless', 1),
#  ('uneared', 1),
#  ('husbandry', 14),
#  ('he', 6682),
#  ('fond', 58),
#  ('tomb', 54),
#  ('love', 2198),
#  ('stop', 95),
#  ('calls', 92),
#  ('lovely', 53),
#  ('april', 18),
#  ('her', 3850),
#  ('shalt', 295),
#  ('despite', 53),
#  ('wrinkles', 14),
#  ('live', 514),
#  ('single', 60),
#  ('image', 46),
#  ('dies', 103),
#  ('why', 1476),
#  ('upon', 1761),
#  ('legacy', 5),
#  ('doth', 940),
#  ('frank', 13),
#  ('beauteous', 39),
#  ('niggard', 8),
#  ('bounteous', 18),
#  ('profitless', 3),
#  ('sums', 17),
#  ('yet', 1577),
#  ('traffic', 12),
#  ('leave', 657),
#  ('unused', 5),
#  ('tombed', 1),
#  ('executor', 2),
#  ('hours', 140),
#  ('gentle', 372),
#  ('frame', 46),
#  ('dwell', 41),
#  ('very', 814),
#  ('unfair', 1),
#  ('fairly', 46),
#  ('summer', 89),
#  ('there', 2212),
#  ('frost', 12),
#  ('leaves', 72),
#  ('quite', 86),
#  ('er', 625),
#  ('bareness', 4),
#  ('pent', 11),
#  ('walls', 85),
#  ('bereft', 17),
#  ('remembrance', 63),
#  ('was', 2250),
#  ('flowers', 46),
#  ('though', 634),
#  ('meet', 328),
#  ('leese', 1),
#  ('substance', 41),
#  ('let', 2369),
#  ('ragged', 24),
#  ('deface', 4),
#  ('vial', 5),
#  ('killed', 8),
#  ('usury', 4),
#  ('happies', 1),
#  ('pay', 141),
#  ('willing', 40),
#  ('ten', 155),
#  ('depart', 66),
#  ('living', 121),
#  ('willed', 2),
#  ('worms', 24),
#  ('lo', 74),
#  ('orient', 5),
#  ('burning', 51),
#  ('head', 537),
#  ('appearing', 10),
#  ('looks', 214),
#  ('sacred', 47),
#  ('resembling', 4),
#  ('middle', 22),
#  ('mortal', 98),
#  ('pilgrimage', 16),
#  ('highmost', 2),
#  ('pitch', 36),
#  ('weary', 78),
#  ('reeleth', 1),
#  ('low', 106),
#  ('way', 571),
#  ('out', 1416),
#  ('noon', 17),
#  ('unlooked', 2),
#  ('diest', 22),
#  ('son', 721),
#  ('8', 8),
#  ('music', 203),
#  ('hear', 884),
#  ('sweets', 16),
#  ('delights', 20),
#  ('annoy', 9),
#  ('true', 818),
#  ('concord', 9),
#  ('sounds', 47),
#  ('unions', 1),
#  ('married', 152),
#  ('offend', 60),
#  ('ear', 199),
#  ('mark', 258),
#  ('husband', 327),
#  ('strikes', 47),
#  ('mutual', 15),
#  ('pleasing', 22),
#  ('sing', 144),
#  ('speechless', 13),
#  ('sings', 91),
#  ('none', 469),
#  ('9', 6),
#  ('fear', 676),
#  ('wet', 19),
#  ('consum', 7),
#  ('makeless', 1),
#  ('weep', 171),
#  ('hast', 585),
#  ('private', 66),
#  ('shape', 87),
#  ('mind', 366),
#  ('shifts', 7),
#  ('enjoys', 7),
#  ('end', 358),
#  ('kept', 98),
#  ('toward', 103),
#  ('bosom', 131),
#  ('sits', 59),
#  ('commits', 5),
#  ('10', 3),
#  ('unprovident', 1),
#  ('grant', 111),
#  ('beloved', 31),
#  ('evident', 7),
#  ('hate', 179),
#  ('gainst', 101),
#  ('chief', 109),
#  ('change', 157),
#  ('thought', 377),
#  ('i', 22538),
#  ('lodged', 5),
#  ('presence', 106),
#  ('hearted', 38),
#  ('wane', 2),
#  ('call', 753),
#  ('convertest', 1),
#  ('cease', 48),
#  ('threescore', 6),
#  ('year', 101),
#  ('would', 2301),
#  ('store', 40),
#  ('featureless', 1),
#  ('best', 450),
#  ('gave', 232),
#  ('gift', 66),
#  ('carved', 6),
#  ('seal', 96),
#  ('tells', 42),
#  ('brave', 160),
#  ('sunk', 4),
#  ('night', 816),
#  ('behold', 163),
#  ('past', 151),
#  ('curls', 4),
#  ('lofty', 18),
#  ('barren', 41),
#  ('green', 114),
#  ('girded', 2),
#  ('sheaves', 1),
#  ('borne', 83),
#  ('bier', 6),
#  ('question', 156),
#  ('go', 1741),
#  ('beauties', 13),
#  ('themselves', 159),
#  ('forsake', 25),
#  ('scythe', 7),
#  ('save', 213),
#  ('longer', 113),
#  ('yours', 256),
#  ('against', 596),
#  ('prepare', 67),
#  ('semblance', 19),
#  ('lease', 9),
#  ('determination', 6),
#  ('again', 769),
#  ('after', 420),
#  ('house', 569),
#  ('fall', 356),
#  ('honour', 632),
#  ('uphold', 5),
#  ('stormy', 4),
#  ('gusts', 7),
#  ('rage', 121),
#  ('unthrifts', 2),
#  ('know', 1742),
#  ('father', 1076),
#  ('14', 1),
#  ('judgement', 16),
#  ('pluck', 139),
#  ('methinks', 152),
#  ('good', 2834),
#  ('evil', 63),
#  ('plagues', 14),
#  ('dearths', 1),
#  ('quality', 55),
#  ('minutes', 16),
#  ('pointing', 9),
#  ('rain', 67),
#  ('princes', 103),
#  ('predict', 1),
#  ('knowledge', 78),
#  ('derive', 12),
#  ('them', 1980),
#  ('wouldst', 131),
#  ('convert', 10),
#  ('consider', 58),
#  ('grows', 77),
#  ('holds', 82),
#  ('perfection', 25),
#  ('huge', 35),
#  ('stage', 37),
#  ('presenteth', 4),
#  ('whereon', 30),
#  ('secret', 65),
#  ('influence', 10),
#  ('cheered', 2),
#  ('sky', 41),
#  ('vaunt', 3),
#  ('youthful', 31),
#  ('wear', 205),
#  ('state', 316),
#  ('conceit', 42),
#  ('inconstant', 11),
#  ('sets', 28),
#  ('before', 841),
#  ('debateth', 1),
#  ('engraft', 1),
#  ('16', 1),
#  ('wherefore', 141),
#  ('mightier', 7),
#  ('bloody', 229),
#  ('fortify', 7),
#  ('means', 267),
#  ('blessed', 79),
#  ('rhyme', 34),
#  ('stand', 586),
#  ('maiden', 50),
#  ('unset', 1),
#  ('liker', 3),
#  ('painted', 53),
#  ('counterfeit', 55),
#  ('pupil', 12),
#  ('inward', 28),
#  ('keeps', 76),
#  ('17', 1),
#  ('believe', 240),
#  ('verse', 32),
#  ('filled', 4),
#  ('high', 262),
#  ('deserts', 21),
#  ('numbers', 46),
#  ('poet', 64),
#  ('touches', 26),
#  ('touched', 3),
#  ('earthly', 32),
#  ('papers', 16),
#  ('yellowed', 1),
#  ('termed', 2),
#  ('compare', 25),
#  ('shake', 102),
#  ('short', 106),
#  ('sometime', 77),
#  ('hot', 261),
#  ('shines', 29),
#  ('gold', 222),
#  ('complexion', 40),
#  ('declines', 4),
#  ('chance', 104),
#  ('lose', 208),
#  ('possession', 34),
#  ('ow', 9),
#  ('wand', 23),
#  ('rest', 358),
#  ('shade', 27),
#  ('19', 1),
#  ('devouring', 7),
#  ('blunt', 68),
#  ('lion', 119),
#  ('paws', 3),
#  ('earth', 317),
#  ('brood', 8),
#  ('keen', 24),
#  ('teeth', 56),
#  ('tiger', 18),
#  ('lived', 20),
#  ('fleet', 26),
#  ('footed', 11),
#  ('heinous', 17),
#  ('carve', 10),
#  ('draw', 210),
#  ('pattern', 15),
#  ('succeeding', 8),
#  ('worst', 105),
#  ('ever', 608),
#  ('young', 467),
#  ('20', 2),
#  ('master', 844),
#  ('passion', 108),
#  ('heart', 1061),
#  ('acquainted', 40),
#  ('shifting', 2),
#  ('women', 181),
#  ('theirs', 31),
#  ('gilding', 2),
#  ('whereupon', 14),
#  ('hue', 27),
#  ('controlling', 5),
#  ('souls', 114),
#  ('created', 20),
#  ('till', 619),
#  ('defeated', 4),
#  ('pricked', 1),
#  ('21', 1),
#  ('muse', 31),
#  ('stirred', 1),
#  ('sun', 237),
#  ('sea', 247),
#  ('gems', 4),
#  ('things', 334),
#  ('rare', 57),
#  ('rondure', 1),
#  ('hems', 2),
#  ('truly', 172),
#  ('hearsay', 2),
#  ('22', 1),
#  ('am', 2168),
#  ('furrows', 1),
#  ('expiate', 2),
#  ('elder', 43),
#  ('nurse', 209),
#  ('ill', 279),
#  ('slain', 127),
#  ('actor', 13),
#  ('put', 500),
#  ('replete', 9),
#  ('strength', 124),
#  ('weakens', 2),
#  ('perfect', 55),
#  ('ceremony', 28),
#  ('burthen', 6),
#  ('eloquence', 11),
#  ('plead', 48),
#  ('belongs', 18),
#  ('fine', 96),
#  ('24', 1),
#  ('played', 7),
#  ('tis', 1408),
#  ('pictured', 1),
#  ('shop', 13),
#  ('hanging', 41),
#  ('glazed', 3),
#  ('turns', 55),
#  ('peep', 20),
#  ('therein', 56),
#  ('grace', 597),
#  ('titles', 20),
#  ('bars', 14),
#  ('pride', 111),
#  ('frown', 52),
#  ('glory', 88),
#  ('painful', 8),
#  ('fight', 283),
#  ('thousand', 325),
#  ('victories', 5),
#  ('once', 421),
#  ('book', 107),
#  ('forgot', 89),
#  ('toiled', 1),
#  ('remove', 32),
#  ('removed', 21),
#  ('26', 1),
#  ('duty', 152),
#  ('strongly', 29),
#  ('embassage', 6),
#  ('witness', 128),
#  ('poor', 631),
#  ('wanting', 22),
#  ('naked', 52),
#  ('points', 31),
#  ('aspect', 26),
#  ('loving', 118),
#  ('dare', 208),
#  ('haste', 163),
#  ('begins', 55),
#  ('journey', 29),
#  ('far', 286),
#  ('abide', 38),
#  ('zealous', 6),
#  ('drooping', 10),
#  ('open', 161),
#  ('looking', 41),
#  ('presents', 15),
#  ('shadow', 81),
#  ('sightless', 5),
#  ('hung', 25),
#  ('thus', 782),
#  ('quiet', 77),
#  ('debarred', 1),
#  ('benefit', 39),
#  ('eased', 2),
#  ('oppressed', 7),
#  ('complain', 17),
#  ('farther', 43),
#  ('blot', 22),
#  ('swart', 4),
#  ('gild', 13),
#  ('nightly', 22),
#  ('length', 38),
#  ('stronger', 38),
#  ('29', 1),
#  ('disgrace', 49),
#  ('outcast', 3),
#  ('trouble', 77),
#  ('cries', 63),
#  ('featured', 1),
#  ('scope', 29),
#  ('these', 1327),
#  ('despising', 3),
#  ('haply', 45),
#  ('hymns', 4),
#  ('gate', 64),
#  ('wealth', 72),
#  ('brings', 53),
#  ('scorn', 108),
#  ('kings', 117),
#  ('summon', 17),
#  ('lack', 119),
#  ('precious', 78),
#  ('afresh', 5),
#  ('cancelled', 1),
#  ('grieve', 40),
#  ('foregone', 3),
#  ('heavily', 13),
#  ('sad', 165),
#  ('account', 46),
#  ('bemoaned', 1),
#  ('losses', 15),
#  ('restored', 6),
#  ('endeared', 4),
#  ('reigns', 15),
#  ('religious', 21),
#  ('interest', 29),
#  ('appear', 151),
#  ('hidden', 8),
#  ('lie', 327),
#  ('loved', 47),
#  ('bones', 76),
#  ('survey', 17),
#  ('outstripped', 1),
#  ('reserve', 9),
#  ('vouchsafe', 52),
#  ('dearer', 23),
#  ('equipage', 2),
#  ('poets', 6),
#  ('style', 19),
#  ('33', 1),
#  ('full', 444),
#  ('glorious', 41),
#  ('seen', 268),
#  ('meadows', 3),
#  ('pale', 135),
#  ('streams', 11),
#  ('ride', 57),
#  ('forlorn', 18),
#  ('hide', 110),
#  ('triumphant', 14),
#  ('alack', 78),
#  ('region', 15),
#  ('cloud', 27),
#  ('disdaineth', 2),
#  ('suns', 10),
#  ('staineth', 1),
#  ('34', 1),
#  ('cloak', 28),
#  ('hiding', 10),
#  ('brav', 8),
#  ('rotten', 38),
#  ('storm', 59),
#  ('beaten', 50),
#  ('salve', 11),
#  ('speak', 1206),
#  ('loss', 118),
#  ('offender', 15),
#  ('bears', 107),
#  ('offence', 96),
#  ('cross', 101),
#  ('tears', 284),
#  ('pearl', 26),
#  ('sheds', 3),
#  ('ransom', 59),
#  ('deeds', 118),
#  ('roses', 32),
#  ('silver', 69),
#  ('fountains', 4),
#  ('both', 646),
#  ('loathsome', 16),
#  ('authorizing', 1),
#  ('trespass', 18),
#  ('sensual', 4),
#  ('fault', 170),
#  ('bring', 449),
#  ('advocate', 9),
#  ('lawful', 61),
#  ('plea', 9),
#  ('commence', 5),
#  ('needs', 147),
#  ('thief', 68),
#  ('sourly', 3),
#  ('robs', 8),
#  ('confess', 146),
#  ('two', 713),
#  ('twain', 38),
#  ('loves', 198),
#  ('help', 327),
#  ('sole', 26),
#  ('steal', 84),
#  ('delight', 56),
#  ('evermore', 25),
#  ('acknowledge', 19),
#  ('lest', 146),
#  ('bewailed', 1),
#  ('guilt', 28),
#  ('take', 1212),
#  ('name', 667),
#  ('decrepit', 3),
#  ('active', 9),
#  ('dearest', 56),
#  ('entitled', 1),
#  ('engrafted', 1),
#  ('despised', 14),
#  ('invent', 7),
#  ('pour', 43),
#  ('excellent', 119),
#  ('thanks', 171),
#  ('invention', 30),
#  ('tenth', 10),
#  ('rhymers', 2),
#  ('curious', 13),
#  ('pain', 67),
#  ('us', 1678),
#  ('separation', 5),
#  ('deserv', 42),
#  ('40', 1),
#  ('blame', 83),
#  ('usest', 5),
#  ('deceivest', 1),
#  ('wilful', 15),
#  ('refusest', 1),
#  ('forgive', 74),
#  ('known', 188),
#  ('injury', 30),
#  ('lascivious', 15),
#  ('kill', 322),
#  ('foes', 73),
#  ('pretty', 117),
#  ('wrongs', 73),
#  ('absent', 34),
#  ('years', 188),
#  ('befits', 9),
#  ('temptation', 5),
#  ('follows', 68),
#  ('woos', 5),
#  ('mightst', 27),
#  ('forbear', 58),
#  ('straying', 4),
#  ('forced', 14),
#  ('hers', 52),
#  ('said', 383),
#  ('dearly', 42),
#  ('wailing', 6),
#  ('ye', 292),
#  ('suff', 15),
#  ('losing', 22),
#  ('wink', 32),
#  ('unrespected', 2),
#  ('darkly', 8),
#  ('dark', 83),
#  ('shadows', 28),
#  ('clear', 66),
#  ('imperfect', 6),
#  ('heavy', 169),
#  ('nights', 38),
#  ('44', 1),
#  ('dull', 113),
#  ('injurious', 15),
#  ('distance', 27),
#  ('space', 29),
#  ('remote', 8),
#  ('matter', 357),
#  ('farthest', 14),
#  ('nimble', 26),
#  ('jump', 13),
#  ('kills', 29),
#  ('large', 72),
#  ('miles', 21),
#  ('water', 149),
#  ('attend', 119),
#  ('badges', 4),
#  ('45', 1),
#  ('purging', 3),
#  ('fire', 268),
#  ('wherever', 6),
#  ('motion', 81),
#  ('slide', 5),
#  ('quicker', 2),
#  ('embassy', 14),
#  ('four', 151),
#  ('down', 663),
#  ('melancholy', 70),
#  ('until', 76),
#  ('recured', 1),
#  ('messengers', 34),
#  ('assured', 16),
#  ('told', 233),
#  ('bar', 37),
#  ('pierced', 3),
#  ('says', 238),
#  ('appearance', 13),
#  ('impanelled', 1),
#  ('tenants', 5),
#  ('verdict', 8),
#  ('determined', 4),
#  ('betwixt', 56),
#  ('league', 34),
#  ('took', 164),
#  ('feast', 101),
#  ('guest', 37),
#  ('share', 28),
#  ('move', 98),
#  ('48', 1),
#  ('careful', 23),
#  ('trifle', 25),
#  ('truest', 11),
#  ('sure', 292),
#  ('jewels', 27),
#  ('trifles', 15),
#  ('greatest', 51),
#  ('prey', 41),
#  ('closure', 3),
#  ('proves', 17),
#  ('prize', 47),
#  ('cast', 101),
#  ('pass', 188),
#  ('settled', 17),
#  ('gravity', 14),
#  ('uprear', 3),
#  ('guard', 129),
#  ('allege', 2),
#  ('50', 2),
#  ('repose', 25),
#  ('plods', 1),
#  ('instinct', 16),
#  ('rider', 8),
#  ('speed', 240),
#  ('provoke', 16),
#  ('sometimes', 61),
#  ('anger', 60),
#  ('thrusts', 6),
#  ('answers', 24),
#  ('groan', 37),
#  ('onward', 3),
#  ('winged', 15),
#  ('race', 17),
#  ('towards', 70),
#  ('run', 201),
#  ('blunting', 2),
#  ('point', 146),
#  ('feasts', 17),
#  ('set', 474),
#  ('stones', 61),
#  ('thinly', 3),
#  ('wardrobe', 5),
#  ('robe', 20),
#  ('instant', 61),
#  ('53', 1),
#  ('whereof', 82),
#  ('millions', 8),
#  ('strange', 252),
#  ('describe', 2),
#  ('poorly', 7),
#  ('helen', 85),
#  ('tires', 6),
#  ('external', 7),
#  ('54', 1),
#  ('deem', 12),
#  ('blooms', 1),
#  ('perfumed', 4),
#  ('hang', 238),
#  ('discloses', 1),
#  ('virtue', 195),
#  ('unwooed', 1),
#  ('distills', 1),
#  ('marble', 17),
#  ('gilded', 21),
#  ('monuments', 6),
#  ('contents', 27),
#  ('unswept', 3),
#  ('stone', 67),
#  ('besmeared', 1),
#  ('root', 44),
#  ('masonry', 2),
#  ('mars', 45),
#  ('quick', 111),
#  ('record', 23),
#  ('enmity', 19),
#  ('room', 74),
#  ('56', 1),
#  ('renew', 15),
#  ('edge', 42),
#  ('feeding', 16),
#  ('morrow', 326),
#  ('fill', 96),
#  ('hungry', 26),
#  ('fulness', 5),
#  ('spirit', 265),
#  ('interim', 11),
#  ('ocean', 29),
#  ('thrice', 86),
#  ('57', 1),
#  ('watch', 207),
#  ('bid', 342),
#  ('adieu', 101),
#  ('jealous', 50),
#  ...]

# %%
unsorted.map(lambda t: (t[1], t[0])).sortByKey(False).collect()

# %%
sc.stop()

# %%
sc
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>
