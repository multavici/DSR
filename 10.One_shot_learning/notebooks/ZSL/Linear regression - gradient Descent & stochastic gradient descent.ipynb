# %%
import numpy as np
from matplotlib import pyplot as plt
import random

# %%
def generateSample(N):
    
    # add your implementation
    
    # generate X with shape (N,1)
    X = np.random.randn(N, 1)
    # append ones to each x in X, then X will be of shape (N,2)
    X = np.c_[np.ones(N) , X]
    # generate Y with shape (N,1)
    Y = np.random.randn(N,1)
    
    return X, Y

# %%
def fitModel_gradient(X, Y):
    Nu = len(X)
    
    # add your implementation
    
    # initialize weights W with shape (2,1) 
    W = np.zeros((X.shape[1],1))
    # foreach epoch
    for epoch in range(number_of_epochs):
        # 1. Calculate predictions P = X * W
        P = np.dot(X, W)
        print(P.shape)
        error = P - Y
        gradient = np.dot(np.transpose(X), error / N)
        W = W - np.dot(lr_gd, gradient)
        
        
        '''
        print(epoch)
        P = np.dot(X, W)
        print('p', P.shape)
        # 2. Calculate error = P - Y 
        error = P - Y
        print('error', error.shape)
        # 3. Calculate gradient = X.T * error / N
        gradient = np.dot(np.transpose(X), error / N)
        print('gradient', gradient.shape)
        # 4. Update weights  W = W - lr * gradient
        print(W.shape)
        W = W - np.transpose(lr * gradient)
        print(W.shape)'''
    return W
    
def fitModel_stochastic_gradient(X, Y):
    
    N = len(X)
    W = np.zeros((X.shape[1],1))

    for epoch in range(number_of_epochs):
        
        # Shuffle training samples (careful to shuffle X and Y in the same order!)
        np.random.seed(123)
        X = np.random.permutation(X)
        np.random.seed(123)
        Y = np.random.permutation(Y)

        for i in range(N):
            error = np.dot(X[i], W) -Y[i]
            gradient = np.dot(X[i].T, error)
            W = W - lr_st * gradient
        
        """
        for xi, yi in zip(X,Y):
            # 1. Calculate sample prediction pi =W0+W1 xi
            pi = np.dot(np.expand_dims(xi, axis=0), W)
            print('pi', pi.shape)
            # 2. Calculate error = pi - yi
            error = pi - yi
            print('error', error.shape)
            # 3. Calculate gradient = xi * error 
            gradient = xi * error
            print('gradient', gradient.shape)
            # 4. Update weights  W = W - lr * gradient
            W = W - lr*gradient"""
    return W

# %%
def plotModel(x, y, w):
    plt.plot(x[:,1], y, "x")
    plt.plot(x[:,1], np.dot(x, w), "r-")
    plt.show()

# %%
N = 20
number_of_epochs = 100
lr_gd = 0.01
lr_st = 0.01

X, Y = generateSample(N)
w_gd = fitModel_gradient(X, Y)
w_sgd = fitModel_stochastic_gradient(X, Y)
plotModel(X,Y,w_gd)
plotModel(X,Y,w_sgd)
# Out:
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# (20, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-002e4c57716e> in <module>
#       6 X, Y = generateSample(N)
#       7 w_gd = fitModel_gradient(X, Y)
# ----> 8 w_sgd = fitModel_stochastic_gradient(X, Y)
#       9 plotModel(X,Y,w_gd)
#      10 plotModel(X,Y,w_sgd)
#
# <ipython-input-36-2200c3af86ce> in fitModel_stochastic_gradient(X, Y)
#      47         for i in range(N):
#      48             error = np.dot(X[i], W) -Y[i]
# ---> 49             gradient = np.dot(X[i].T, error)
#      50             W = W - lr_st * gradient
#      51
#
# ValueError: shapes (2,) and (1,) not aligned: 2 (dim 0) != 1 (dim 0)
