# %% [markdown]
# # What is Pandas?
#
# Pandas is a [package](https://data36.com/python-import-built-in-modules-data-science/) in Python, used for data formatting, analysis and manipulation. It gives you a way to deal with 2-D data structures (like SQL or Excel tables) in Python, which isn't "native" to the language. That's why we have to `import` the package. If you have Conda, you've already downloaded Pandas, we don't have to download it. By `import`-ing the package, we just allow the current .py or .ipynb file we're working on to use the functionality of the package.
#
# ### Why pandas?
# - 2-D table-like data structures are intuitively known to us. Everyone is used to seeing Excel tables and this feels comfortable to work with. It is also what business people and other stakeholders will be used to seeing.
# - It's one of the quickest ways to "automate the boring stuff" and lets you add value to any team quickly.
# - It plays well with other packages & libraries like SK-learn.
#
#
# For reference, you can use this great pandas [cheat sheet](https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf)

# %%
import pandas as pd

# %% [markdown]
# ## Pandas Data Types
#
# Pandas has 2 main data types:
# - Series:
#     - 1-D data structure. Different from a numpy array in that each value has a unique ID.
#
#
# - DataFrame:
#     - 2(+)-D data structure (better known as a table w/ named columns & numbered rows).
#
# Here, we will focus on DataFrames, because if you can do something in 2-D, you can also probably do it in 1-D! Also, 2(+)-D data structures are much more useful to know how to work with in data science (you can't train a model with only 1 single array of data).

# %% [markdown]
# ### Importing a DataFrame
# Throughout this tutorial, we will use practice data sets.
# Here, we use a dataset of wine reviews.

# %%
wine = pd.read_csv('data/wine_reviews/winemag-data_first150k.csv', index_col=0)

# %% [markdown]
# ### Quickly viewing data
# df - calling the DataFrame by name will show the entire thing, or, up to a set number of rows. you can configure this number in the notebook settings.
#
# df.head() - shows first 5 rows _in order imported_! This is important as it is not sorted. So, the first row you see may not be the "actual" first row, or the first row you expect to see.
#
# df.tail() - shows last 5 rows in order of imported.
#
# All 3 are useful to quickly get a feel for your data.

# %%
wine
# Out:
#             country                                        description  \
# 0                US  This tremendous 100% varietal wine hails from ...
# 1             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# 5             Spain  Deep, dense and pure from the opening bell, th...
# 6             Spain  Slightly gritty black-fruit aromas include a s...
# 7             Spain  Lush cedary black-fruit aromas are luxe and of...
# 8                US  This re-named vineyard was formerly bottled as...
# 9                US  The producer sources from two blocks of the vi...
# 10            Italy  Elegance, complexity and structure come togeth...
# 11               US  From 18-year-old vines, this supple well-balan...
# 12               US  A standout even in this terrific lineup of 201...
# 13           France  This wine is in peak condition. The tannins an...
# 14               US  With its sophisticated mix of mineral, acid an...
# 15               US  First made in 2006, this succulent luscious Ch...
# 16               US  This blockbuster, powerhouse of a wine suggest...
# 17            Spain  Nicely oaked blackberry, licorice, vanilla and...
# 18           France  Coming from a seven-acre vineyard named after ...
# 19               US  This fresh and lively medium-bodied wine is be...
# 20               US  Heitz has made this stellar rosé from the rare...
# 21            Spain  Alluring, complex and powerful aromas of grill...
# 22            Spain  Tarry blackberry and cheesy oak aromas are app...
# 23               US  The apogee of this ambitious winery's white wi...
# 24               US  San Jose-based producer Adam Comartin heads 1,...
# 25      New Zealand  Yields were down in 2015, but intensity is up,...
# 26               US  Bergström has made a Shea designate since 2003...
# 27               US  Focused and dense, this intense wine captures ...
# 28               US  Cranberry, baked rhubarb, anise and crushed sl...
# 29               US  This standout Rocks District wine brings earth...
# ...             ...                                                ...
# 150900        Chile  Aromas of freshly cut lumber, complete with so...
# 150901        Chile  Lavishly oaked, the fruit here struggles to ma...
# 150902        Chile  This medium weight Chardonnay offered aromas o...
# 150903        Chile  Very light berry and mint aromas open this aus...
# 150904        Chile  A lot of Chilean Cabernets seem to have a dist...
# 150905        Chile  There's not much point in making a reserve-sty...
# 150906       France  This lovely wine, a Monopole, is already showi...
# 150907       France  Rion holds back on the new oak, letting the pu...
# 150908       France  Another premier cru from Michel Gros, this one...
# 150909       France  This is a lovely, fragrant Burgundy, with a sm...
# 150910       France  Scents of graham cracker and malted milk choco...
# 150911       France  This needs a good bit of breathing time, then ...
# 150912       France  The nose is dominated by the attractive scents...
# 150913       France  Inky and rustic, yet in a refined manner. This...
# 150914           US  Old-gold in color, and thick and syrupy. The a...
# 150915           US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916           US  An impressive wine that presents a full bouque...
# 150917       France  Light and elegant, this spicy, lively wine is ...
# 150918       France  Jacquart makes a full-bodied, ripe style of Ch...
# 150919       France  This classy example opens with a very floral n...
# 150920        Italy  Rich and mature aromas of smoke, earth and her...
# 150921       France  Shows some older notes: a bouquet of toasted w...
# 150922        Italy  Made by 30-ish Roberta Borghese high above Man...
# 150923       France  Rich and toasty, with tiny bubbles. The bouque...
# 150924       France  Really fine for a low-acid vintage, there's an...
# 150925        Italy  Many people feel Fiano represents southern Ita...
# 150926       France  Offers an intriguing nose with ginger, lime an...
# 150927        Italy  This classic example comes from a cru vineyard...
# 150928       France  A perfect salmon shade, with scents of peaches...
# 150929        Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# 1       Carodorum Selección Especial Reserva      96  110.0
# 2              Special Selected Late Harvest      96   90.0
# 3                                    Reserve      96   65.0
# 4                                 La Brûlade      95   66.0
# 5                                  Numanthia      95   73.0
# 6                                  San Román      95   65.0
# 7                    Carodorum Único Crianza      95  110.0
# 8                                     Silice      95   65.0
# 9                       Gap's Crown Vineyard      95   60.0
# 10                        Ronco della Chiesa      95   80.0
# 11           Estate Vineyard Wadensvil Block      95   48.0
# 12                            Weber Vineyard      95   48.0
# 13                   Château Montus Prestige      95   90.0
# 14                            Grace Vineyard      95  185.0
# 15                                    Sigrid      95   90.0
# 16                           Rainin Vineyard      95  325.0
# 17                    6 Años Reserva Premium      95   80.0
# 18                             Le Pigeonnier      95  290.0
# 19                      Gap's Crown Vineyard      95   75.0
# 20                                Grignolino      95   24.0
# 21                   Prado Enea Gran Reserva      95   79.0
# 22                                Termanthia      95  220.0
# 23                             Giallo Solare      95   60.0
# 24                             R-Bar-R Ranch      95   45.0
# 25                           Maté's Vineyard      94   57.0
# 26                             Shea Vineyard      94   62.0
# 27                                   Abetina      94  105.0
# 28                           Garys' Vineyard      94   60.0
# 29                           The Funk Estate      94   60.0
# ...                                      ...     ...    ...
# 150900                         Prima Reserva      81   13.0
# 150901                               Reserva      81   12.0
# 150902                        Estate Bottled      81   10.0
# 150903                                   120      81    7.0
# 150904                                   NaN      81   10.0
# 150905                         Prima Reserva      80   13.0
# 150906                         Clos des Reas      93   65.0
# 150907                       Les Beaux-Monts      92   52.0
# 150908                           Aux Brulees      90   65.0
# 150909                  Clos dea Argillieres      89   52.0
# 150910                                   NaN      89   38.0
# 150911                          Les Chaliots      87   37.0
# 150912                           Les Charmes      87   65.0
# 150913                                   NaN      94   30.0
# 150914           Late Harvest Cluster Select      94   25.0
# 150915                           Nightingale      93   30.0
# 150916                             J. Schram      93   65.0
# 150917                         Brut Mosaïque      92   30.0
# 150918                        Cuvée Mosaïque      92   38.0
# 150919                       Cuvée President      91   37.0
# 150920                          Brut Riserva      91   19.0
# 150921         Blanc de Blancs Brut Mosaïque      91   38.0
# 150922                             Superiore      91    NaN
# 150923                              Demi-Sec      91   30.0
# 150924                          Diamant Bleu      91   70.0
# 150925                                   NaN      91   20.0
# 150926                        Cuvée Prestige      91   27.0
# 150927                         Terre di Dora      91   20.0
# 150928                       Grand Brut Rosé      90   52.0
# 150929                                   NaN      90   15.0
#
#                   province                    region_1  \
# 0               California                 Napa Valley
# 1           Northern Spain                        Toro
# 2               California              Knights Valley
# 3                   Oregon           Willamette Valley
# 4                 Provence                      Bandol
# 5           Northern Spain                        Toro
# 6           Northern Spain                        Toro
# 7           Northern Spain                        Toro
# 8                   Oregon          Chehalem Mountains
# 9               California                Sonoma Coast
# 10      Northeastern Italy                      Collio
# 11                  Oregon                Ribbon Ridge
# 12                  Oregon                Dundee Hills
# 13        Southwest France                     Madiran
# 14                  Oregon                Dundee Hills
# 15                  Oregon           Willamette Valley
# 16              California   Diamond Mountain District
# 17          Northern Spain            Ribera del Duero
# 18        Southwest France                      Cahors
# 19              California                Sonoma Coast
# 20              California                 Napa Valley
# 21          Northern Spain                       Rioja
# 22          Northern Spain                        Toro
# 23              California                 Edna Valley
# 24              California        Santa Cruz Mountains
# 25                   Kumeu                         NaN
# 26                  Oregon           Willamette Valley
# 27                  Oregon           Willamette Valley
# 28              California       Santa Lucia Highlands
# 29              Washington     Walla Walla Valley (WA)
# ...                    ...                         ...
# 150900        Maipo Valley                         NaN
# 150901        Maipo Valley                         NaN
# 150902        Maipo Valley                         NaN
# 150903        Rapel Valley                         NaN
# 150904        Maipo Valley                         NaN
# 150905        Maipo Valley                         NaN
# 150906            Burgundy               Vosne-Romanée
# 150907            Burgundy               Vosne-Romanée
# 150908            Burgundy               Vosne-Romanée
# 150909            Burgundy           Nuits-St.-Georges
# 150910            Burgundy           Chambolle-Musigny
# 150911            Burgundy           Nuits-St.-Georges
# 150912            Burgundy           Chambolle-Musigny
# 150913        Rhône Valley         Châteauneuf-du-Pape
# 150914          California             Anderson Valley
# 150915          California                 North Coast
# 150916          California                 Napa Valley
# 150917           Champagne                   Champagne
# 150918           Champagne                   Champagne
# 150919           Champagne                   Champagne
# 150920  Northeastern Italy                      Trento
# 150921           Champagne                   Champagne
# 150922  Northeastern Italy  Colli Orientali del Friuli
# 150923           Champagne                   Champagne
# 150924           Champagne                   Champagne
# 150925      Southern Italy           Fiano di Avellino
# 150926           Champagne                   Champagne
# 150927      Southern Italy           Fiano di Avellino
# 150928           Champagne                   Champagne
# 150929  Northeastern Italy                  Alto Adige
#
#                        region_2                variety  \
# 0                          Napa     Cabernet Sauvignon
# 1                           NaN          Tinta de Toro
# 2                        Sonoma        Sauvignon Blanc
# 3             Willamette Valley             Pinot Noir
# 4                           NaN     Provence red blend
# 5                           NaN          Tinta de Toro
# 6                           NaN          Tinta de Toro
# 7                           NaN          Tinta de Toro
# 8             Willamette Valley             Pinot Noir
# 9                        Sonoma             Pinot Noir
# 10                          NaN               Friulano
# 11            Willamette Valley             Pinot Noir
# 12            Willamette Valley             Pinot Noir
# 13                          NaN                 Tannat
# 14            Willamette Valley             Pinot Noir
# 15            Willamette Valley             Chardonnay
# 16                         Napa     Cabernet Sauvignon
# 17                          NaN            Tempranillo
# 18                          NaN                 Malbec
# 19                       Sonoma             Pinot Noir
# 20                         Napa                   Rosé
# 21                          NaN      Tempranillo Blend
# 22                          NaN          Tinta de Toro
# 23                Central Coast             Chardonnay
# 24                Central Coast             Pinot Noir
# 25                          NaN             Chardonnay
# 26                          NaN             Pinot Noir
# 27            Willamette Valley             Pinot Noir
# 28                Central Coast             Pinot Noir
# 29              Columbia Valley                  Syrah
# ...                         ...                    ...
# 150900                      NaN     Cabernet Sauvignon
# 150901                      NaN                 Merlot
# 150902                      NaN             Chardonnay
# 150903                      NaN     Cabernet Sauvignon
# 150904                      NaN     Cabernet Sauvignon
# 150905                      NaN                 Merlot
# 150906                      NaN             Pinot Noir
# 150907                      NaN             Pinot Noir
# 150908                      NaN             Pinot Noir
# 150909                      NaN             Pinot Noir
# 150910                      NaN             Pinot Noir
# 150911                      NaN             Pinot Noir
# 150912                      NaN             Pinot Noir
# 150913                      NaN  Rhône-style Red Blend
# 150914  Mendocino/Lake Counties         White Riesling
# 150915              North Coast            White Blend
# 150916                     Napa        Champagne Blend
# 150917                      NaN        Champagne Blend
# 150918                      NaN        Champagne Blend
# 150919                      NaN        Champagne Blend
# 150920                      NaN        Champagne Blend
# 150921                      NaN        Champagne Blend
# 150922                      NaN                  Tocai
# 150923                      NaN        Champagne Blend
# 150924                      NaN        Champagne Blend
# 150925                      NaN            White Blend
# 150926                      NaN        Champagne Blend
# 150927                      NaN            White Blend
# 150928                      NaN        Champagne Blend
# 150929                      NaN           Pinot Grigio
#
#                          winery
# 0                         Heitz
# 1       Bodega Carmen Rodríguez
# 2                      Macauley
# 3                         Ponzi
# 4          Domaine de la Bégude
# 5                     Numanthia
# 6                      Maurodos
# 7       Bodega Carmen Rodríguez
# 8                     Bergström
# 9                     Blue Farm
# 10             Borgo del Tiglio
# 11       Patricia Green Cellars
# 12       Patricia Green Cellars
# 13            Vignobles Brumont
# 14               Domaine Serene
# 15                    Bergström
# 16                         Hall
# 17                     Valduero
# 18           Château Lagrézette
# 19                 Gary Farrell
# 20                        Heitz
# 21                         Muga
# 22                    Numanthia
# 23             Center of Effort
# 24                     Comartin
# 25                  Kumeu River
# 26                    Bergström
# 27                        Ponzi
# 28                         Roar
# 29                       Saviah
# ...                         ...
# 150900               De Martino
# 150901                Undurraga
# 150902               De Martino
# 150903               Santa Rita
# 150904               De Martino
# 150905               De Martino
# 150906              Michel Gros
# 150907              Daniel Rion
# 150908              Michel Gros
# 150909              Daniel Rion
# 150910              Michel Gros
# 150911              Michel Gros
# 150912              Daniel Rion
# 150913          Le Vieux Donjon
# 150914                  Navarro
# 150915                 Beringer
# 150916              Schramsberg
# 150917                 Jacquart
# 150918                 Jacquart
# 150919                H.Germain
# 150920                  Letrari
# 150921                 Jacquart
# 150922        Ronchi di Manzano
# 150923                 Jacquart
# 150924  Heidsieck & Co Monopole
# 150925    Feudi di San Gregorio
# 150926                H.Germain
# 150927                Terredora
# 150928                   Gosset
# 150929            Alois Lageder
#
# [150930 rows x 10 columns]

# %% [markdown]
# df.shape - shows number of (rows, columns)

# %%
wine.shape
# Out:
# (150930, 10)

# %% [markdown]
# df.shape returns a tuple. We can use tuple indexes to quickly access just one of these.
# **How many rows does our data have?**

# %%
wine.shape[0]
# Out:
# 150930

# %% [markdown]
# We can also quickly look at the data types of each of our columns.

# %%
wine.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %% [markdown]
# Everything non-numeric is an object

# %% [markdown]
# ## Initial Data Exploration with Pandas
# ### Selecting Data
# Anyone who knows SQL knows how important it is to be able to select particular columns or rows.
# In Pandas, there are a lot of different ways to select.
#
# ### Selecting by column name
# 2 ways:

# %%
# 1. With quotes
wine['price']
# wine[['price', 'province']] if you want more than 1 column
# returned table is a copy
# Out:
#         price            province
# 0       235.0          California
# 1       110.0      Northern Spain
# 2        90.0          California
# 3        65.0              Oregon
# 4        66.0            Provence
# 5        73.0      Northern Spain
# 6        65.0      Northern Spain
# 7       110.0      Northern Spain
# 8        65.0              Oregon
# 9        60.0          California
# 10       80.0  Northeastern Italy
# 11       48.0              Oregon
# 12       48.0              Oregon
# 13       90.0    Southwest France
# 14      185.0              Oregon
# 15       90.0              Oregon
# 16      325.0          California
# 17       80.0      Northern Spain
# 18      290.0    Southwest France
# 19       75.0          California
# 20       24.0          California
# 21       79.0      Northern Spain
# 22      220.0      Northern Spain
# 23       60.0          California
# 24       45.0          California
# 25       57.0               Kumeu
# 26       62.0              Oregon
# 27      105.0              Oregon
# 28       60.0          California
# 29       60.0          Washington
# ...       ...                 ...
# 150900   13.0        Maipo Valley
# 150901   12.0        Maipo Valley
# 150902   10.0        Maipo Valley
# 150903    7.0        Rapel Valley
# 150904   10.0        Maipo Valley
# 150905   13.0        Maipo Valley
# 150906   65.0            Burgundy
# 150907   52.0            Burgundy
# 150908   65.0            Burgundy
# 150909   52.0            Burgundy
# 150910   38.0            Burgundy
# 150911   37.0            Burgundy
# 150912   65.0            Burgundy
# 150913   30.0        Rhône Valley
# 150914   25.0          California
# 150915   30.0          California
# 150916   65.0          California
# 150917   30.0           Champagne
# 150918   38.0           Champagne
# 150919   37.0           Champagne
# 150920   19.0  Northeastern Italy
# 150921   38.0           Champagne
# 150922    NaN  Northeastern Italy
# 150923   30.0           Champagne
# 150924   70.0           Champagne
# 150925   20.0      Southern Italy
# 150926   27.0           Champagne
# 150927   20.0      Southern Italy
# 150928   52.0           Champagne
# 150929   15.0  Northeastern Italy
#
# [150930 rows x 2 columns]

# %%
# 2. With period (NOTE - ONLY works when column names have no spaces!)
wine.price
# Out:
# 0         235.0
# 1         110.0
# 2          90.0
# 3          65.0
# 4          66.0
# 5          73.0
# 6          65.0
# 7         110.0
# 8          65.0
# 9          60.0
# 10         80.0
# 11         48.0
# 12         48.0
# 13         90.0
# 14        185.0
# 15         90.0
# 16        325.0
# 17         80.0
# 18        290.0
# 19         75.0
# 20         24.0
# 21         79.0
# 22        220.0
# 23         60.0
# 24         45.0
# 25         57.0
# 26         62.0
# 27        105.0
# 28         60.0
# 29         60.0
#           ...
# 150900     13.0
# 150901     12.0
# 150902     10.0
# 150903      7.0
# 150904     10.0
# 150905     13.0
# 150906     65.0
# 150907     52.0
# 150908     65.0
# 150909     52.0
# 150910     38.0
# 150911     37.0
# 150912     65.0
# 150913     30.0
# 150914     25.0
# 150915     30.0
# 150916     65.0
# 150917     30.0
# 150918     38.0
# 150919     37.0
# 150920     19.0
# 150921     38.0
# 150922      NaN
# 150923     30.0
# 150924     70.0
# 150925     20.0
# 150926     27.0
# 150927     20.0
# 150928     52.0
# 150929     15.0
# Name: price, Length: 150930, dtype: float64

# %% [markdown]
# We can also chain together functions (commands) in Pandas:

# %%
wine.price.head()
# wine['price'].head()
# Out:
# 0    235.0
# 1    110.0
# 2     90.0
# 3     65.0
# 4     66.0
# Name: price, dtype: float64

# %% [markdown]
# ## Slicing - Precise Selection by Row and Column
# - `df.loc` gets rows (or columns) with particular labels from the index.
# - `df.iloc` gets rows (or columns) at particular positions in the index (so it only takes integers).
#
#
# **When using `loc` and `iloc`, the row is ALWAYS 1st and column is ALWAYS second!! **
#
# **[row:row, column:column]**
#
# Notice how each defaults if you leave one side blank.

# %%
wine.iloc[0:5, 3:5]
# Out:
#    points  price
# 0      96  235.0
# 1      96  110.0
# 2      96   90.0
# 3      96   65.0
# 4      95   66.0

# %%
wine.iloc[:5]
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %% [markdown]
# To see how these two are different, we will change the index.

# %%
import random

# %%
random_index = random.sample(list(wine.index), k=len(list(wine.index)))
wine['scrambled_index'] = random_index
scrambled_wine = wine.set_index('scrambled_index')

# %%
# returns all rows up to the 5th position.
scrambled_wine.iloc[:5]
# Out:
#                 country                                        description  \
# scrambled_index
# 60340                US  This tremendous 100% varietal wine hails from ...
# 27723             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 105491               US  Mac Watson honors the memory of a wine once ma...
# 51574                US  This spent 20 months in 30% new French oak, an...
# 121150           France  This is the top wine from La Bégude, named aft...
#
#                                           designation  points  price  \
# scrambled_index
# 60340                               Martha's Vineyard      96  235.0
# 27723            Carodorum Selección Especial Reserva      96  110.0
# 105491                  Special Selected Late Harvest      96   90.0
# 51574                                         Reserve      96   65.0
# 121150                                     La Brûlade      95   66.0
#
#                        province           region_1           region_2  \
# scrambled_index
# 60340                California        Napa Valley               Napa
# 27723            Northern Spain               Toro                NaN
# 105491               California     Knights Valley             Sonoma
# 51574                    Oregon  Willamette Valley  Willamette Valley
# 121150                 Provence             Bandol                NaN
#
#                             variety                   winery
# scrambled_index
# 60340            Cabernet Sauvignon                    Heitz
# 27723                 Tinta de Toro  Bodega Carmen Rodríguez
# 105491              Sauvignon Blanc                 Macauley
# 51574                    Pinot Noir                    Ponzi
# 121150           Provence red blend     Domaine de la Bégude

# %%
# returns all rows up to where #5 is in the index. Since we scrambled it, this is no longer in the 5th position.
scrambled_wine.loc[:5]
# Out:
#                      country  \
# scrambled_index
# 60340                     US
# 27723                  Spain
# 105491                    US
# 51574                     US
# 121150                France
# 134143                 Spain
# 91803                  Spain
# 103913                 Spain
# 5476                      US
# 125520                    US
# 2107                   Italy
# 96230                     US
# 33770                     US
# 132503                France
# 54614                     US
# 116858                    US
# 73671                     US
# 85606                  Spain
# 88995                 France
# 89295                     US
# 37567                     US
# 27055                  Spain
# 12730                  Spain
# 21161                     US
# 7275                      US
# 110918           New Zealand
# 24457                     US
# 128616                    US
# 103555                    US
# 58774                     US
# ...                      ...
# 64259                     US
# 139072                    US
# 43453                  Italy
# 54996                  Spain
# 9293                   Italy
# 140879                 Italy
# 131269                    US
# 101312              Portugal
# 143155                    US
# 63040                  Spain
# 88248                  Spain
# 17662                     US
# 11831                     US
# 90                        US
# 43048                     US
# 87109              Australia
# 102751                 Spain
# 12364                Germany
# 72322                Germany
# 526                    Italy
# 129422           New Zealand
# 137746                France
# 136316                France
# 31682                 France
# 79190                  Italy
# 3332                  France
# 114809               Germany
# 130469                France
# 21573                     US
# 5                    Germany
#
#                                                        description  \
# scrambled_index
# 60340            This tremendous 100% varietal wine hails from ...
# 27723            Ripe aromas of fig, blackberry and cassis are ...
# 105491           Mac Watson honors the memory of a wine once ma...
# 51574            This spent 20 months in 30% new French oak, an...
# 121150           This is the top wine from La Bégude, named aft...
# 134143           Deep, dense and pure from the opening bell, th...
# 91803            Slightly gritty black-fruit aromas include a s...
# 103913           Lush cedary black-fruit aromas are luxe and of...
# 5476             This re-named vineyard was formerly bottled as...
# 125520           The producer sources from two blocks of the vi...
# 2107             Elegance, complexity and structure come togeth...
# 96230            From 18-year-old vines, this supple well-balan...
# 33770            A standout even in this terrific lineup of 201...
# 132503           This wine is in peak condition. The tannins an...
# 54614            With its sophisticated mix of mineral, acid an...
# 116858           First made in 2006, this succulent luscious Ch...
# 73671            This blockbuster, powerhouse of a wine suggest...
# 85606            Nicely oaked blackberry, licorice, vanilla and...
# 88995            Coming from a seven-acre vineyard named after ...
# 89295            This fresh and lively medium-bodied wine is be...
# 37567            Heitz has made this stellar rosé from the rare...
# 27055            Alluring, complex and powerful aromas of grill...
# 12730            Tarry blackberry and cheesy oak aromas are app...
# 21161            The apogee of this ambitious winery's white wi...
# 7275             San Jose-based producer Adam Comartin heads 1,...
# 110918           Yields were down in 2015, but intensity is up,...
# 24457            Bergström has made a Shea designate since 2003...
# 128616           Focused and dense, this intense wine captures ...
# 103555           Cranberry, baked rhubarb, anise and crushed sl...
# 58774            This standout Rocks District wine brings earth...
# ...                                                            ...
# 64259            Fresh, clean and frankly delicious, this Sauvi...
# 139072           This delicious wine captures the exotic side o...
# 43453            Delicate mineral nuances frame a refined, swee...
# 54996            Pretty pear, apple and other dusty white-fruit...
# 9293             Here is a very likeable Prosecco with lime fla...
# 140879           This Chardonnay-based sparkler (with 10% Pinot...
# 131269           Shows the earthiness that often marks young Ca...
# 101312           It's the Antão Vaz, the Chardonnay of Portugal...
# 143155           There's lots of acidity in this young wine, wh...
# 63040            A barrel-heavy blend of Sauvignon Blanc and Ve...
# 88248            Light, floral and almondy, with hints of pear,...
# 17662            A chewy style, with lots of earthy, organic fl...
# 11831            This Bordeaux-Rhône blend is tannic and hard i...
# 90               A little heavy and overly extracted. Shows lot...
# 43048            Very light fruit flavors of citrus and yellow ...
# 87109            Though a tad simple in the mouth, the nose has...
# 102751           Dark, fiery, forceful and woody, with aromas o...
# 12364            Notes of botrytis, carnations and spring veget...
# 72322            A cozy, likable wine, with gardenia, honeycomb...
# 526              This is a subdued expression of Extra Dry Pros...
# 129422           This off-dry Riesling features an alluring nos...
# 137746           There is some good depth here, giving a wine w...
# 136316           This is the second label of Château Cantinot, ...
# 31682            Very fresh grassy aromas mark this Sauvignon B...
# 79190            This light rosé sparkler from Canella boasts a...
# 3332             Light, fresh, fruity wine, with a smoky comple...
# 114809           Opens with a candied note, cut through with sp...
# 130469           The wine has some weight, dominated by dry tan...
# 21573            This is an acid-lover's Pinot Gris, quite tart...
# 5                Unusual aromatics are dominated by hints of zu...
#
#                                                        designation  points  \
# scrambled_index
# 60340                                            Martha's Vineyard      96
# 27723                         Carodorum Selección Especial Reserva      96
# 105491                               Special Selected Late Harvest      96
# 51574                                                      Reserve      96
# 121150                                                  La Brûlade      95
# 134143                                                   Numanthia      95
# 91803                                                    San Román      95
# 103913                                     Carodorum Único Crianza      95
# 5476                                                        Silice      95
# 125520                                        Gap's Crown Vineyard      95
# 2107                                            Ronco della Chiesa      95
# 96230                              Estate Vineyard Wadensvil Block      95
# 33770                                               Weber Vineyard      95
# 132503                                     Château Montus Prestige      95
# 54614                                               Grace Vineyard      95
# 116858                                                      Sigrid      95
# 73671                                              Rainin Vineyard      95
# 85606                                       6 Años Reserva Premium      95
# 88995                                                Le Pigeonnier      95
# 89295                                         Gap's Crown Vineyard      95
# 37567                                                   Grignolino      95
# 27055                                      Prado Enea Gran Reserva      95
# 12730                                                   Termanthia      95
# 21161                                                Giallo Solare      95
# 7275                                                 R-Bar-R Ranch      95
# 110918                                             Maté's Vineyard      94
# 24457                                                Shea Vineyard      94
# 128616                                                     Abetina      94
# 103555                                             Garys' Vineyard      94
# 58774                                              The Funk Estate      94
# ...                                                            ...     ...
# 64259                                                     Rosa Lee      88
# 139072                                            Paragon Vineyard      88
# 43453                                                     Cartizze      88
# 54996                                                     MPX Brut      88
# 9293                                              Pianer Extra Dry      88
# 140879                                               Arte Italiana      88
# 131269                                               Reed Vineyard      88
# 101312                                             Branco Colheita      88
# 143155                                                         NaN      88
# 63040                                                     Tríptico      85
# 88248                                                          NaN      85
# 17662                                             Momtazi Vineyard      85
# 11831                                                Study in Blue      85
# 90                                                             NaN      85
# 43048                                                          NaN      85
# 87109            Church Block Cabernet Sauvignon - Shiraz - Merlot      85
# 102751                                                         NaN      85
# 12364                                     Kirchberg Bingen Trocken      85
# 72322                                                          NaN      85
# 526                                                Lovrè Extra Dry      85
# 129422                                                         NaN      85
# 137746                                                         NaN      85
# 136316                                                 Haut Boutet      85
# 31682                                                          NaN      85
# 79190                                                    Rosé Brut      85
# 3332                                                           NaN      85
# 114809                                          Kugelspiel Trocken      85
# 130469                                                         NaN      85
# 21573                                                          NaN      85
# 5                                                     Malterdinger      85
#
#                  price            province  \
# scrambled_index
# 60340            235.0          California
# 27723            110.0      Northern Spain
# 105491            90.0          California
# 51574             65.0              Oregon
# 121150            66.0            Provence
# 134143            73.0      Northern Spain
# 91803             65.0      Northern Spain
# 103913           110.0      Northern Spain
# 5476              65.0              Oregon
# 125520            60.0          California
# 2107              80.0  Northeastern Italy
# 96230             48.0              Oregon
# 33770             48.0              Oregon
# 132503            90.0    Southwest France
# 54614            185.0              Oregon
# 116858            90.0              Oregon
# 73671            325.0          California
# 85606             80.0      Northern Spain
# 88995            290.0    Southwest France
# 89295             75.0          California
# 37567             24.0          California
# 27055             79.0      Northern Spain
# 12730            220.0      Northern Spain
# 21161             60.0          California
# 7275              45.0          California
# 110918            57.0               Kumeu
# 24457             62.0              Oregon
# 128616           105.0              Oregon
# 103555            60.0          California
# 58774             60.0          Washington
# ...                ...                 ...
# 64259             20.0          California
# 139072            20.0          California
# 43453              NaN              Veneto
# 54996             11.0           Catalonia
# 9293              17.0              Veneto
# 140879            12.0  Northeastern Italy
# 131269            50.0          California
# 101312             NaN          Alentejano
# 143155            16.0          California
# 63040             25.0      Northern Spain
# 88248              8.0      Northern Spain
# 17662             33.0              Oregon
# 11831             45.0          California
# 90                20.0          California
# 43048             18.0              Oregon
# 87109             20.0     South Australia
# 102751            16.0       Central Spain
# 12364              NaN         Rheinhessen
# 72322             14.0            Rheingau
# 526               15.0              Veneto
# 129422            15.0       Central Otago
# 137746             NaN            Bordeaux
# 136316            27.0            Bordeaux
# 31682             17.0            Bordeaux
# 79190              NaN              Veneto
# 3332              51.0            Bordeaux
# 114809            24.0             Franken
# 130469            17.0            Bordeaux
# 21573             15.0              Oregon
# 5                 47.0               Baden
#
#                                                     region_1  \
# scrambled_index
# 60340                                            Napa Valley
# 27723                                                   Toro
# 105491                                        Knights Valley
# 51574                                      Willamette Valley
# 121150                                                Bandol
# 134143                                                  Toro
# 91803                                                   Toro
# 103913                                                  Toro
# 5476                                      Chehalem Mountains
# 125520                                          Sonoma Coast
# 2107                                                  Collio
# 96230                                           Ribbon Ridge
# 33770                                           Dundee Hills
# 132503                                               Madiran
# 54614                                           Dundee Hills
# 116858                                     Willamette Valley
# 73671                              Diamond Mountain District
# 85606                                       Ribera del Duero
# 88995                                                 Cahors
# 89295                                           Sonoma Coast
# 37567                                            Napa Valley
# 27055                                                  Rioja
# 12730                                                   Toro
# 21161                                            Edna Valley
# 7275                                    Santa Cruz Mountains
# 110918                                                   NaN
# 24457                                      Willamette Valley
# 128616                                     Willamette Valley
# 103555                                 Santa Lucia Highlands
# 58774                                Walla Walla Valley (WA)
# ...                                                      ...
# 64259                                            Napa Valley
# 139072                                           Edna Valley
# 43453                         Prosecco Superiore di Cartizze
# 54996                                                   Cava
# 9293                  Prosecco di Conegliano e Valdobbiadene
# 140879                                                Trento
# 131269                                          Mount Harlan
# 101312                                                   NaN
# 143155                                  Russian River Valley
# 63040                   Vino de la Tierra de Castilla y León
# 88248                                                Navarra
# 17662                                      Willamette Valley
# 11831                                            Napa Valley
# 90                                             Sonoma Valley
# 43048                                           Dundee Hills
# 87109                                           McLaren Vale
# 102751                                             La Mancha
# 12364                                                    NaN
# 72322                                                    NaN
# 526              Conegliano Valdobbiadene Prosecco Superiore
# 129422                                                   NaN
# 137746                                                 Médoc
# 136316                              Premieres Côtes de Blaye
# 31682                                         Bordeaux Blanc
# 79190                                                 Veneto
# 3332                                                 Pomerol
# 114809                                                   NaN
# 130469                                            Haut-Médoc
# 21573                                                 Oregon
# 5                                                        NaN
#
#                           region_2                     variety  \
# scrambled_index
# 60340                         Napa          Cabernet Sauvignon
# 27723                          NaN               Tinta de Toro
# 105491                      Sonoma             Sauvignon Blanc
# 51574            Willamette Valley                  Pinot Noir
# 121150                         NaN          Provence red blend
# 134143                         NaN               Tinta de Toro
# 91803                          NaN               Tinta de Toro
# 103913                         NaN               Tinta de Toro
# 5476             Willamette Valley                  Pinot Noir
# 125520                      Sonoma                  Pinot Noir
# 2107                           NaN                    Friulano
# 96230            Willamette Valley                  Pinot Noir
# 33770            Willamette Valley                  Pinot Noir
# 132503                         NaN                      Tannat
# 54614            Willamette Valley                  Pinot Noir
# 116858           Willamette Valley                  Chardonnay
# 73671                         Napa          Cabernet Sauvignon
# 85606                          NaN                 Tempranillo
# 88995                          NaN                      Malbec
# 89295                       Sonoma                  Pinot Noir
# 37567                         Napa                        Rosé
# 27055                          NaN           Tempranillo Blend
# 12730                          NaN               Tinta de Toro
# 21161                Central Coast                  Chardonnay
# 7275                 Central Coast                  Pinot Noir
# 110918                         NaN                  Chardonnay
# 24457                          NaN                  Pinot Noir
# 128616           Willamette Valley                  Pinot Noir
# 103555               Central Coast                  Pinot Noir
# 58774              Columbia Valley                       Syrah
# ...                            ...                         ...
# 64259                         Napa             Sauvignon Blanc
# 139072               Central Coast                    Viognier
# 43453                          NaN                    Prosecco
# 54996                          NaN             Sparkling Blend
# 9293                           NaN                    Prosecco
# 140879                         NaN             Sparkling Blend
# 131269               Central Coast                  Pinot Noir
# 101312                         NaN            Portuguese White
# 143155                      Sonoma                  Chardonnay
# 63040                          NaN     Verdejo-Sauvignon Blanc
# 88248                          NaN                 White Blend
# 17662            Willamette Valley                  Pinot Noir
# 11831                         Napa                   Red Blend
# 90                          Sonoma          Cabernet Sauvignon
# 43048            Willamette Valley                 Pinot Blanc
# 87109                          NaN              Cabernet Blend
# 102751                         NaN                 Tempranillo
# 12364                          NaN                    Riesling
# 72322                          NaN                    Riesling
# 526                            NaN                       Glera
# 129422                         NaN                    Riesling
# 137746                         NaN    Bordeaux-style Red Blend
# 136316                         NaN    Bordeaux-style Red Blend
# 31682                          NaN  Bordeaux-style White Blend
# 79190                          NaN             Sparkling Blend
# 3332                           NaN                      Merlot
# 114809                         NaN                    Silvaner
# 130469                         NaN    Bordeaux-style Red Blend
# 21573                 Oregon Other                  Pinot Gris
# 5                              NaN                  Pinot Noir
#
#                                   winery
# scrambled_index
# 60340                              Heitz
# 27723            Bodega Carmen Rodríguez
# 105491                          Macauley
# 51574                              Ponzi
# 121150              Domaine de la Bégude
# 134143                         Numanthia
# 91803                           Maurodos
# 103913           Bodega Carmen Rodríguez
# 5476                           Bergström
# 125520                         Blue Farm
# 2107                    Borgo del Tiglio
# 96230             Patricia Green Cellars
# 33770             Patricia Green Cellars
# 132503                 Vignobles Brumont
# 54614                     Domaine Serene
# 116858                         Bergström
# 73671                               Hall
# 85606                           Valduero
# 88995                 Château Lagrézette
# 89295                       Gary Farrell
# 37567                              Heitz
# 27055                               Muga
# 12730                          Numanthia
# 21161                   Center of Effort
# 7275                            Comartin
# 110918                       Kumeu River
# 24457                          Bergström
# 128616                             Ponzi
# 103555                              Roar
# 58774                             Saviah
# ...                                  ...
# 64259                                 ZD
# 139072                           Tangent
# 43453                   Maccari Spumanti
# 54996                   Mas de Monistrol
# 9293                          Le Colture
# 140879                            Rotari
# 131269                            Calera
# 101312                           Cartuxa
# 143155                          De Loach
# 63040                      Storks' Tower
# 88248                        Vega Sindoa
# 17662                              Verve
# 11831                         Waterstone
# 90                            Wellington
# 43048                      Winter's Hill
# 87109                        Wirra Wirra
# 102751                            Volver
# 12364                          Rheingraf
# 72322                    Schumann-Nägler
# 526                       Serre Spumanti
# 129422                             Mohua
# 137746                 Barton & Guestier
# 136316                  Château Cantinot
# 31682               Château de Rouquette
# 79190                            Canella
# 3332                 Château Tour Robert
# 114809                           Castell
# 130469                  Château d'Esteau
# 21573                          Cloudline
# 5                                  Huber
#
# [103881 rows x 10 columns]

# %% [markdown]
# Including columns:

# %%
scrambled_wine.iloc[:5, :5]
# Out:
#                 country                                        description  \
# scrambled_index
# 60340                US  This tremendous 100% varietal wine hails from ...
# 27723             Spain  Ripe aromas of fig, blackberry and cassis are ...
# 105491               US  Mac Watson honors the memory of a wine once ma...
# 51574                US  This spent 20 months in 30% new French oak, an...
# 121150           France  This is the top wine from La Bégude, named aft...
#
#                                           designation  points  price
# scrambled_index
# 60340                               Martha's Vineyard      96  235.0
# 27723            Carodorum Selección Especial Reserva      96  110.0
# 105491                  Special Selected Late Harvest      96   90.0
# 51574                                         Reserve      96   65.0
# 121150                                     La Brûlade      95   66.0

# %% [markdown]
# **Question:**
# What happens when you try to use `.loc` with column selectors, instead of `.iloc`?

# %%
scrambled_wine.loc[:5, :5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-f0a1e35c0776> in <module>
# ----> 1 scrambled_wine.loc[:5, :5]
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     888                 continue
#     889
# --> 890             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     891
#     892         return retval
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1864         if isinstance(key, slice):
#    1865             self._validate_key(key, axis)
# -> 1866             return self._get_slice_axis(key, axis=axis)
#    1867         elif com.is_bool_indexer(key):
#    1868             return self._getbool_axis(key, axis=axis)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1509         labels = obj._get_axis(axis)
#    1510         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop,
# -> 1511                                        slice_obj.step, kind=self.name)
#    1512
#    1513         if isinstance(indexer, slice):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    4105         """
#    4106         start_slice, end_slice = self.slice_locs(start, end, step=step,
# -> 4107                                                  kind=kind)
#    4108
#    4109         # return a slice
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    4312         end_slice = None
#    4313         if end is not None:
# -> 4314             end_slice = self.get_slice_bound(end, 'right', kind)
#    4315         if end_slice is None:
#    4316             end_slice = len(self)
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    4232         # For datetime indices label may be a string that has to be converted
#    4233         # to datetime boundary according to its resolution.
# -> 4234         label = self._maybe_cast_slice_bound(label, side, kind)
#    4235
#    4236         # we need to look up the label
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    4183         # this is rejected (generally .loc gets you here)
#    4184         elif is_integer(label):
# -> 4185             self._invalid_indexer('slice', label)
#    4186
#    4187         return label
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in _invalid_indexer(self, form, key)
#    1861                         "indexers [{key}] of {kind}".format(
#    1862                             form=form, klass=type(self), key=key,
# -> 1863                             kind=type(key)))
#    1864
#    1865     def get_duplicates(self):
#
# TypeError: cannot do slice indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [5] of <class 'int'>

# %% [markdown]
# With `df.loc`, we can also use key words.
#
# **Question:** Why doesn't the same work with `.iloc`?

# %%
wine.loc[:5,['variety', 'price']]
# Out:
#               variety  price
# 0  Cabernet Sauvignon  235.0
# 1       Tinta de Toro  110.0
# 2     Sauvignon Blanc   90.0
# 3          Pinot Noir   65.0
# 4  Provence red blend   66.0
# 5       Tinta de Toro   73.0

# %% [markdown]
# ## Exercise:
# Select the first 5 rows and columns "points" and "region_1" of the *scrambled_wine* table.
# Hint: you'll need to string together 2 different types of selectors.

# %%
scrambled_wine.iloc[:5][['points', 'region_1']]
# scrambled_wine[['points', 'region_1']].iloc[:5]
# scrambled_wine[['points', 'region_1']].head()
# Out:
#                  points           region_1
# scrambled_index
# 60340                96        Napa Valley
# 27723                96               Toro
# 105491               96     Knights Valley
# 51574                96  Willamette Valley
# 121150               95             Bandol
